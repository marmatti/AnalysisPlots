# %% [markdown]
# # MDAnalysis Tutorial

# %% [markdown]
# ## Preparations

# %% [markdown]
# ### Loading MDAnalysis

# %%
#!which python
import numpy as np
import MDAnalysis as mda
#from MDAnalysis.tests.datafiles import PSF, DCD, GRO, TRR
from MDAnalysis.analysis import rms
import pandas as pd
#import nglview as nv
import MDAnalysis.transformations
from MDAnalysis.analysis import diffusionmap, align, rms
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
mda.__version__
# Out:
# '2.6.1'

# %%
# !ls

# %% [markdown]
# ## Basics

# %% [markdown]
# ### Universe, AtomGroup and Trajectory
#
# MDAnalysis is an object oriented library, meaning that data from your molecular simulations are made available through various MDAnalysis objects, which will be introduced here.
#
# The first object in any analysis is the `Universe` object, which is the central data structure from which all other objects are created.  This is created through providing a topology (description of the system) and trajectory (description of the temporal data) file.

# %%
#In the case of our sim data, the XTC file is the trajectory_file and TPR is the topology_file, GRO can be used both as topology or trajectory depending on the information given
#In this case, I will not consider the GRO file and before I convert to pdb with trjconv, I will eliminate solvent and centre in CoM of system
#If you follow GROMACS tutorial instructions the XTC is md_0_1_noPBC.xtc
#PREFERRED ALTERNATIVE: gmx trjconv -s input.tpr -f input.xtc -o output.pdb --> mda.Universe('output.pdb')
#u = mda.Universe('topo.pdb', 'trj.pdb')
#u = mda.Universe(PSF, DCD)
u = mda.Universe('trajMolearn_stride_proteinH_center_unwrap.pdb', dt=1000)
#u= mda.Merge(protein)
print(u)
# Out:
# <Universe with 439 atoms>

# %%
aligner = align.AlignTraj(u, u, select='protein and not name H* and resid 47-59',
                          in_memory=True).run()

# %%
ag = u.select_atoms('all')
with MDAnalysis.Writer("alignToOneHelix.pdb", ag.n_atoms) as W:
    for ts in u.trajectory:
        W.write(ag)
# Out:
# /home/marmatt/miniforge3/envs/molearn/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1151: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# /home/marmatt/miniforge3/envs/molearn/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1198: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."

# %%
# Alpha-synuclein

Rgyr2KKW = []
#Rmsd = []
#protein = u.select_atoms("protein and not name H*")
#print(len(protein))
for ts in u.trajectory:
    #R = mda.analysis.rms.RMSD(u, u, select='protein', ref_frame=0)
    #R = rms.rmsd(u, u)-->RIGHT COMMAND (although rmsd and not RMSD)
    #Rmsd.append((u.trajectory.time, R))
    #Rmsd.append((u.trajectory.time, protein.rmsd.RMSD()))
    Rgyr2KKW.append((u.trajectory.time, u.atoms.radius_of_gyration()))
Rgyr2KKW = np.array(Rgyr2KKW)
Rgyr2KKW[:,0] = Rgyr2KKW[:,0]/1000 
df_alpha_syn_rg = pd.DataFrame(Rgyr2KKW, columns=['Time (ns)', 'Rg'])
df_alpha_syn_rg.to_csv('alpha-syn_Rg_data.csv')

# %%
from MDAnalysis.analysis import diffusionmap, align, rms
#calculate pairwise-RMSD
#protein = u.select_atoms("protein and not name H*")
matrix = diffusionmap.DistanceMatrix(u, select='name CA').run()

df_alpha_syn_pairRMSD = pd.DataFrame(matrix.dist_matrix)

df_alpha_syn_pairRMSD.to_csv('alpha-syn_pairRMSD_data.csv')
# Out:
# /home/marmatt/miniforge3/envs/molearn/lib/python3.10/site-packages/MDAnalysis/analysis/diffusionmap.py:288: DeprecationWarning: The `dist_matrix` attribute was deprecated in MDAnalysis 2.0.0 and will be removed in MDAnalysis 3.0.0. Please use `results.dist_matrix` instead.
#   warnings.warn(wmsg, DeprecationWarning)

# %% [markdown]
# ## Trajectory Analysis
#
# The `Universe` binds together the static topology (which atoms, how are they connected, what un-changing properties do the atoms possess (such as partial charge), ...) and the changing coordinate information, which is stored in the trajectory.
#
# The length of a trajectory (number of frames) is

# %%
#to include timestep u = mda.Universe('topo.pdb', 'trj.pdb', dt=)
#u = mda.Universe('topo.pdb', 'trj.pdb')
#u = mda.Universe(PSF, DCD)
#WHY DO I NEED TO SPECIFY DT HERE, DT=10 Since i sample every 10ps and mdAnalysis defaults to 1ps RIGHT??
u = mda.Universe('traj_center_fit.pdb', dt=10)
#uw = mda.Universe('lyso.pdb', dt=10)
#ref = mda.Universe('mdAnalysis.pdb', dt=10)
len(u.trajectory)
#len(uw.trajectory)

# %%
'''
Jasmin's universe function
'''
#def get_universe(file_path: str) -> tuple:
def get_universe() -> tuple:
    """
    get GRO, XTC files and return universe
    """
    #topology = file_path + "npt.gro"
    #trajectory = file_path + "md_0_1.xtc"
    topology = "npt.gro"
    trajectory = "md_0_1.xtc"
    u = mda.Universe(topology, trajectory, topology_format="GRO")
    return u 
#print(get_universe('~/Documents/asyn_setup_august_23/AnalysisOfFirstTrajectory/') )
print(get_universe())

# %%
topology = "npt.gro"
trajectory = "md_0_1.xtc"
u = mda.Universe(topology, trajectory, topology_format="GRO")
len(u.trajectory)

# %%
print(u)

# %% [markdown]
# The standard way to assess each time step (or frame) in a trajectory is to iterate over the `Universe.trajectory` attribute (which is an instance of Reader class):

# %%
for ts in u.trajectory:
    print("Frame: %5d, Time: %8.3f ps" % (ts.frame, u.trajectory.time))
    print("Rgyr: %g A" % (u.atoms.radius_of_gyration(), ))
'''
for tz in uw.trajectory:
    print("Frame: %5d, Time: %8.3f ps" % (tz.frame, uw.trajectory.time))
    print("Rgyr: %g A" % (u.atoms.radius_of_gyration(), ))
'''
# Out:
# Rgyr: 35.3242 A
# Frame:   142, Time: 1420.000 ps
# Rgyr: 35.1764 A
# Frame:   143, Time: 1430.000 ps
# Rgyr: 35.4619 A
# Frame:   144, Time: 1440.000 ps
# Rgyr: 35.1966 A
# Frame:   145, Time: 1450.000 ps
# Rgyr: 35.3407 A
# Frame:   146, Time: 1460.000 ps
# Rgyr: 35.1544 A
# Frame:   147, Time: 1470.000 ps
# Rgyr: 35.1886 A
# Frame:   148, Time: 1480.000 ps
# Rgyr: 35.1157 A
# Frame:   149, Time: 1490.000 ps
# Rgyr: 35.4788 A
# Frame:   150, Time: 1500.000 ps
# Rgyr: 35.4505 A
# Frame:   151, Time: 1510.000 ps
# Rgyr: 35.3061 A
# Frame:   152, Time: 1520.000 ps
# Rgyr: 35.2369 A
# Frame:   153, Time: 1530.000 ps
# Rgyr: 35.0235 A
# Frame:   154, Time: 1540.000 ps
# Rgyr: 35.4291 A
# Frame:   155, Time: 1550.000 ps
# Rgyr: 34.9696 A
# Frame:   156, Time: 1560.000 ps
# Rgyr: 34.6533 A
# Frame:   157, Time: 1570.000 ps
# Rgyr: 34.8472 A
# Frame:   158, Time: 1580.000 ps
# Rgyr: 34.8591 A
# Frame:   159, Time: 1590.000 ps
# Rgyr: 34.6372 A
# Frame:   160, Time: 1600.000 ps
# Rgyr: 34.7391 A
# Frame:   161, Time: 1610.000 ps
# Rgyr: 34.8819 A
# Frame:   162, Time: 1620.000 ps
# Rgyr: 34.796 A
# Frame:   163, Time: 1630.000 ps
# Rgyr: 34.5395 A
# Frame:   164, Time: 1640.000 ps
# Rgyr: 34.8845 A
# Frame:   165, Time: 1650.000 ps
# Rgyr: 34.6367 A
# Frame:   166, Time: 1660.000 ps
# Rgyr: 34.603 A
# Frame:   167, Time: 1670.000 ps
# Rgyr: 34.3197 A
# Frame:   168, Time: 1680.000 ps
# Rgyr: 34.292 A
# Frame:   169, Time: 1690.000 ps
# Rgyr: 34.6697 A
# Frame:   170, Time: 1700.000 ps
# Rgyr: 34.6579 A
# Frame:   171, Time: 1710.000 ps
# Rgyr: 34.7132 A
# Frame:   172, Time: 1720.000 ps
# Rgyr: 34.5438 A
# Frame:   173, Time: 1730.000 ps
# Rgyr: 34.5728 A
# Frame:   174, Time: 1740.000 ps
# Rgyr: 34.3265 A
# Frame:   175, Time: 1750.000 ps
# Rgyr: 34.5606 A
# Frame:   176, Time: 1760.000 ps
# Rgyr: 34.4954 A
# Frame:   177, Time: 1770.000 ps
# Rgyr: 34.1175 A
# Frame:   178, Time: 1780.000 ps
# Rgyr: 33.9369 A
# Frame:   179, Time: 1790.000 ps
# Rgyr: 33.9729 A
# Frame:   180, Time: 1800.000 ps
# Rgyr: 33.8785 A
# Frame:   181, Time: 1810.000 ps
# Rgyr: 34.0409 A
# Frame:   182, Time: 1820.000 ps
# Rgyr: 34.292 A
# Frame:   183, Time: 1830.000 ps
# Rgyr: 34.0372 A
# Frame:   184, Time: 1840.000 ps
# Rgyr: 33.7447 A
# Frame:   185, Time: 1850.000 ps
# Rgyr: 33.6602 A
# Frame:   186, Time: 1860.000 ps
# Rgyr: 33.6021 A
# Frame:   187, Time: 1870.000 ps
# Rgyr: 33.3252 A
# Frame:   188, Time: 1880.000 ps
# Rgyr: 33.6414 A
# Frame:   189, Time: 1890.000 ps
# Rgyr: 33.5021 A
# Frame:   190, Time: 1900.000 ps
# Rgyr: 33.8038 A
# Frame:   191, Time: 1910.000 ps
# Rgyr: 33.6741 A
# Frame:   192, Time: 1920.000 ps
# Rgyr: 33.691 A
# Frame:   193, Time: 1930.000 ps
# Rgyr: 33.3466 A
# Frame:   194, Time: 1940.000 ps
# Rgyr: 33.1553 A
# Frame:   195, Time: 1950.000 ps
# Rgyr: 33.1265 A
# Frame:   196, Time: 1960.000 ps
# Rgyr: 32.8078 A
# Frame:   197, Time: 1970.000 ps
# Rgyr: 33.2523 A
# Frame:   198, Time: 1980.000 ps
# Rgyr: 33.2653 A
# Frame:   199, Time: 1990.000 ps
# Rgyr: 33.5114 A
# Frame:   200, Time: 2000.000 ps
# Rgyr: 33.2448 A
# Frame:   201, Time: 2010.000 ps
# Rgyr: 33.3768 A
# Frame:   202, Time: 2020.000 ps
# Rgyr: 33.4987 A
# Frame:   203, Time: 2030.000 ps
# Rgyr: 33.6496 A
# Frame:   204, Time: 2040.000 ps
# Rgyr: 33.5408 A
# Frame:   205, Time: 2050.000 ps
# Rgyr: 33.4525 A
# Frame:   206, Time: 2060.000 ps
# Rgyr: 33.3732 A
# Frame:   207, Time: 2070.000 ps
# Rgyr: 33.1863 A
# Frame:   208, Time: 2080.000 ps
# Rgyr: 32.9142 A
# Frame:   209, Time: 2090.000 ps
# Rgyr: 32.8829 A
# Frame:   210, Time: 2100.000 ps
# Rgyr: 33.1168 A
# Frame:   211, Time: 2110.000 ps
# Rgyr: 33.5306 A
# Frame:   212, Time: 2120.000 ps
# Rgyr: 33.5913 A
# Frame:   213, Time: 2130.000 ps
# Rgyr: 33.3058 A
# Frame:   214, Time: 2140.000 ps
# Rgyr: 33.6696 A
# Frame:   215, Time: 2150.000 ps
# Rgyr: 33.58 A
# Frame:   216, Time: 2160.000 ps
# Rgyr: 33.8403 A
# Frame:   217, Time: 2170.000 ps
# Rgyr: 33.9009 A
# Frame:   218, Time: 2180.000 ps
# Rgyr: 33.8849 A
# Frame:   219, Time: 2190.000 ps
# Rgyr: 33.9537 A
# Frame:   220, Time: 2200.000 ps
# Rgyr: 34.4644 A
# Frame:   221, Time: 2210.000 ps
# Rgyr: 34.3683 A
# Frame:   222, Time: 2220.000 ps
# Rgyr: 34.5395 A
# Frame:   223, Time: 2230.000 ps
# Rgyr: 34.2293 A
# Frame:   224, Time: 2240.000 ps
# Rgyr: 34.3581 A
# Frame:   225, Time: 2250.000 ps
# Rgyr: 34.6281 A
# Frame:   226, Time: 2260.000 ps
# Rgyr: 34.6951 A
# Frame:   227, Time: 2270.000 ps
# Rgyr: 34.9783 A
# Frame:   228, Time: 2280.000 ps
# Rgyr: 34.8881 A
# Frame:   229, Time: 2290.000 ps
# Rgyr: 34.6606 A
# Frame:   230, Time: 2300.000 ps
# Rgyr: 34.8448 A
# Frame:   231, Time: 2310.000 ps
# Rgyr: 34.8988 A
# Frame:   232, Time: 2320.000 ps
# Rgyr: 34.8851 A
# Frame:   233, Time: 2330.000 ps
# Rgyr: 34.9197 A
# Frame:   234, Time: 2340.000 ps
# Rgyr: 34.8236 A
# Frame:   235, Time: 2350.000 ps
# Rgyr: 35.2059 A
# Frame:   236, Time: 2360.000 ps
# Rgyr: 35.4326 A
# Frame:   237, Time: 2370.000 ps
# Rgyr: 35.4816 A
# Frame:   238, Time: 2380.000 ps
# Rgyr: 35.5177 A
# Frame:   239, Time: 2390.000 ps
# Rgyr: 35.4562 A
# Frame:   240, Time: 2400.000 ps
# Rgyr: 35.23 A
# Frame:   241, Time: 2410.000 ps
# Rgyr: 34.9756 A
# Frame:   242, Time: 2420.000 ps
# Rgyr: 34.9162 A
# Frame:   243, Time: 2430.000 ps
# Rgyr: 34.7133 A
# Frame:   244, Time: 2440.000 ps
# Rgyr: 34.9226 A
# Frame:   245, Time: 2450.000 ps
# Rgyr: 35.3065 A
# Frame:   246, Time: 2460.000 ps
# Rgyr: 35.1181 A
# Frame:   247, Time: 2470.000 ps
# Rgyr: 34.9233 A
# Frame:   248, Time: 2480.000 ps
# Rgyr: 34.6736 A
# Frame:   249, Time: 2490.000 ps
# Rgyr: 34.9214 A
# Frame:   250, Time: 2500.000 ps
# Rgyr: 34.6603 A
# Frame:   251, Time: 2510.000 ps
# Rgyr: 34.5495 A
# Frame:   252, Time: 2520.000 ps
# Rgyr: 34.6036 A
# Frame:   253, Time: 2530.000 ps
# Rgyr: 34.9074 A
# Frame:   254, Time: 2540.000 ps
# Rgyr: 35.1414 A
# Frame:   255, Time: 2550.000 ps
# Rgyr: 34.9144 A
# Frame:   256, Time: 2560.000 ps
# Rgyr: 35.1213 A
# Frame:   257, Time: 2570.000 ps
# Rgyr: 35.1887 A
# Frame:   258, Time: 2580.000 ps
# Rgyr: 35.2846 A
# Frame:   259, Time: 2590.000 ps
# Rgyr: 35.1381 A
# Frame:   260, Time: 2600.000 ps
# Rgyr: 35.1643 A
# Frame:   261, Time: 2610.000 ps
# Rgyr: 35.1029 A
# Frame:   262, Time: 2620.000 ps
# Rgyr: 35.3263 A
# Frame:   263, Time: 2630.000 ps
# Rgyr: 35.2206 A
# Frame:   264, Time: 2640.000 ps
# Rgyr: 34.9801 A
# Frame:   265, Time: 2650.000 ps
# Rgyr: 34.8544 A
# Frame:   266, Time: 2660.000 ps
# Rgyr: 34.5834 A
# Frame:   267, Time: 2670.000 ps
# Rgyr: 34.5908 A
# Frame:   268, Time: 2680.000 ps
# Rgyr: 34.4979 A
# Frame:   269, Time: 2690.000 ps
# Rgyr: 34.5651 A
# Frame:   270, Time: 2700.000 ps
# Rgyr: 34.3445 A
# Frame:   271, Time: 2710.000 ps
# Rgyr: 34.1132 A
# Frame:   272, Time: 2720.000 ps
# Rgyr: 33.8559 A
# Frame:   273, Time: 2730.000 ps
# Rgyr: 33.7945 A
# Frame:   274, Time: 2740.000 ps
# Rgyr: 33.8153 A
# Frame:   275, Time: 2750.000 ps
# Rgyr: 33.4614 A
# Frame:   276, Time: 2760.000 ps
# Rgyr: 33.4662 A
# Frame:   277, Time: 2770.000 ps
# Rgyr: 33.2405 A
# Frame:   278, Time: 2780.000 ps
# Rgyr: 32.9026 A
# Frame:   279, Time: 2790.000 ps
# Rgyr: 32.8699 A
# Frame:   280, Time: 2800.000 ps
# Rgyr: 33.2138 A
# Frame:   281, Time: 2810.000 ps
# Rgyr: 32.8971 A
# Frame:   282, Time: 2820.000 ps
# Rgyr: 33.0657 A
# Frame:   283, Time: 2830.000 ps
# Rgyr: 33.2683 A
# Frame:   284, Time: 2840.000 ps
# Rgyr: 33.5428 A
# Frame:   285, Time: 2850.000 ps
# Rgyr: 33.6255 A
# Frame:   286, Time: 2860.000 ps
# Rgyr: 33.6491 A
# Frame:   287, Time: 2870.000 ps
# Rgyr: 33.3977 A
# Frame:   288, Time: 2880.000 ps
# Rgyr: 33.3624 A
# Frame:   289, Time: 2890.000 ps
# Rgyr: 33.3745 A
# Frame:   290, Time: 2900.000 ps
# Rgyr: 33.5938 A
# Frame:   291, Time: 2910.000 ps
# Rgyr: 33.5355 A
# Frame:   292, Time: 2920.000 ps
# Rgyr: 33.5706 A
# Frame:   293, Time: 2930.000 ps
# Rgyr: 33.7104 A
# Frame:   294, Time: 2940.000 ps
# Rgyr: 33.5927 A
# Frame:   295, Time: 2950.000 ps
# Rgyr: 33.5051 A
# Frame:   296, Time: 2960.000 ps
# Rgyr: 33.4379 A
# Frame:   297, Time: 2970.000 ps
# Rgyr: 33.4972 A
# Frame:   298, Time: 2980.000 ps
# Rgyr: 33.4827 A
# Frame:   299, Time: 2990.000 ps
# Rgyr: 33.1583 A
# Frame:   300, Time: 3000.000 ps
# Rgyr: 33.3982 A
# Frame:   301, Time: 3010.000 ps
# Rgyr: 33.0708 A
# Frame:   302, Time: 3020.000 ps
# Rgyr: 32.9562 A
# Frame:   303, Time: 3030.000 ps
# Rgyr: 32.9136 A
# Frame:   304, Time: 3040.000 ps
# Rgyr: 32.7219 A
# Frame:   305, Time: 3050.000 ps
# Rgyr: 32.6073 A
# Frame:   306, Time: 3060.000 ps
# Rgyr: 32.805 A
# Frame:   307, Time: 3070.000 ps
# Rgyr: 33.126 A
# Frame:   308, Time: 3080.000 ps
# Rgyr: 32.7545 A
# Frame:   309, Time: 3090.000 ps
# Rgyr: 32.5081 A
# Frame:   310, Time: 3100.000 ps
# Rgyr: 32.6659 A
# Frame:   311, Time: 3110.000 ps
# Rgyr: 32.5524 A
# Frame:   312, Time: 3120.000 ps
# Rgyr: 32.6756 A
# Frame:   313, Time: 3130.000 ps
# Rgyr: 32.92 A
# Frame:   314, Time: 3140.000 ps
# Rgyr: 33.0971 A
# Frame:   315, Time: 3150.000 ps
# Rgyr: 33.162 A
# Frame:   316, Time: 3160.000 ps
# Rgyr: 33.0689 A
# Frame:   317, Time: 3170.000 ps
# Rgyr: 33.1064 A
# Frame:   318, Time: 3180.000 ps
# Rgyr: 33.2388 A
# Frame:   319, Time: 3190.000 ps
# Rgyr: 33.4958 A
# Frame:   320, Time: 3200.000 ps
# Rgyr: 33.6299 A
# Frame:   321, Time: 3210.000 ps
# Rgyr: 33.7799 A
# Frame:   322, Time: 3220.000 ps
# Rgyr: 33.7013 A
# Frame:   323, Time: 3230.000 ps
# Rgyr: 33.9439 A
# Frame:   324, Time: 3240.000 ps
# Rgyr: 34.2826 A
# Frame:   325, Time: 3250.000 ps
# Rgyr: 34.5685 A
# Frame:   326, Time: 3260.000 ps
# Rgyr: 34.1647 A
# Frame:   327, Time: 3270.000 ps
# Rgyr: 34.5156 A
# Frame:   328, Time: 3280.000 ps
# Rgyr: 34.3782 A
# Frame:   329, Time: 3290.000 ps
# Rgyr: 34.6523 A
# Frame:   330, Time: 3300.000 ps
# Rgyr: 34.9145 A
# Frame:   331, Time: 3310.000 ps
# Rgyr: 35.059 A
# Frame:   332, Time: 3320.000 ps
# Rgyr: 35.2057 A
# Frame:   333, Time: 3330.000 ps
# Rgyr: 35.1918 A
# Frame:   334, Time: 3340.000 ps
# Rgyr: 35.3809 A
# Frame:   335, Time: 3350.000 ps
# Rgyr: 35.1785 A
# Frame:   336, Time: 3360.000 ps
# Rgyr: 35.3417 A
# Frame:   337, Time: 3370.000 ps
# Rgyr: 35.3943 A
# Frame:   338, Time: 3380.000 ps
# Rgyr: 35.1135 A
# Frame:   339, Time: 3390.000 ps
# Rgyr: 35.1279 A
# Frame:   340, Time: 3400.000 ps
# Rgyr: 35.2452 A
# Frame:   341, Time: 3410.000 ps
# Rgyr: 35.3304 A
# Frame:   342, Time: 3420.000 ps
# Rgyr: 35.4425 A
# Frame:   343, Time: 3430.000 ps
# Rgyr: 35.2983 A
# Frame:   344, Time: 3440.000 ps
# Rgyr: 35.5247 A
# Frame:   345, Time: 3450.000 ps
# Rgyr: 35.0384 A
# Frame:   346, Time: 3460.000 ps
# Rgyr: 35.2297 A
# Frame:   347, Time: 3470.000 ps
# Rgyr: 34.9947 A
# Frame:   348, Time: 3480.000 ps
# Rgyr: 34.9225 A
# Frame:   349, Time: 3490.000 ps
# Rgyr: 34.3962 A
# Frame:   350, Time: 3500.000 ps
# Rgyr: 34.1774 A
# Frame:   351, Time: 3510.000 ps
# Rgyr: 34.2992 A
# Frame:   352, Time: 3520.000 ps
# Rgyr: 34.3289 A
# Frame:   353, Time: 3530.000 ps
# Rgyr: 34.1665 A
# Frame:   354, Time: 3540.000 ps
# Rgyr: 33.9417 A
# Frame:   355, Time: 3550.000 ps
# Rgyr: 33.8762 A
# Frame:   356, Time: 3560.000 ps
# Rgyr: 33.9155 A
# Frame:   357, Time: 3570.000 ps
# Rgyr: 33.9842 A
# Frame:   358, Time: 3580.000 ps
# Rgyr: 34.1545 A
# Frame:   359, Time: 3590.000 ps
# Rgyr: 34.1474 A
# Frame:   360, Time: 3600.000 ps
# Rgyr: 34.3902 A
# Frame:   361, Time: 3610.000 ps
# Rgyr: 34.2748 A
# Frame:   362, Time: 3620.000 ps
# Rgyr: 34.1462 A
# Frame:   363, Time: 3630.000 ps
# Rgyr: 34.108 A
# Frame:   364, Time: 3640.000 ps
# Rgyr: 34.4545 A
# Frame:   365, Time: 3650.000 ps
# Rgyr: 34.8523 A
# Frame:   366, Time: 3660.000 ps
# Rgyr: 34.6476 A
# Frame:   367, Time: 3670.000 ps
# Rgyr: 34.5898 A
# Frame:   368, Time: 3680.000 ps
# Rgyr: 34.5553 A
# Frame:   369, Time: 3690.000 ps
# Rgyr: 34.9428 A
# Frame:   370, Time: 3700.000 ps
# Rgyr: 34.8364 A
# Frame:   371, Time: 3710.000 ps
# Rgyr: 34.9903 A
# Frame:   372, Time: 3720.000 ps
# Rgyr: 34.9927 A
# Frame:   373, Time: 3730.000 ps
# Rgyr: 34.8756 A
# Frame:   374, Time: 3740.000 ps
# Rgyr: 34.7633 A
# Frame:   375, Time: 3750.000 ps
# Rgyr: 34.7642 A
# Frame:   376, Time: 3760.000 ps
# Rgyr: 34.9576 A
# Frame:   377, Time: 3770.000 ps
# Rgyr: 34.8763 A
# Frame:   378, Time: 3780.000 ps
# Rgyr: 34.8755 A
# Frame:   379, Time: 3790.000 ps
# Rgyr: 35.0915 A
# Frame:   380, Time: 3800.000 ps
# Rgyr: 35.5063 A
# Frame:   381, Time: 3810.000 ps
# Rgyr: 35.7926 A
# Frame:   382, Time: 3820.000 ps
# Rgyr: 35.5783 A
# Frame:   383, Time: 3830.000 ps
# Rgyr: 36.094 A
# Frame:   384, Time: 3840.000 ps
# Rgyr: 35.6878 A
# Frame:   385, Time: 3850.000 ps
# Rgyr: 35.8345 A
# Frame:   386, Time: 3860.000 ps
# Rgyr: 35.3903 A
# Frame:   387, Time: 3870.000 ps
# Rgyr: 35.5603 A
# Frame:   388, Time: 3880.000 ps
# Rgyr: 35.4494 A
# Frame:   389, Time: 3890.000 ps
# Rgyr: 35.5745 A
# Frame:   390, Time: 3900.000 ps
# Rgyr: 35.8283 A
# Frame:   391, Time: 3910.000 ps
# Rgyr: 36.3095 A
# Frame:   392, Time: 3920.000 ps
# Rgyr: 36.1994 A
# Frame:   393, Time: 3930.000 ps
# Rgyr: 35.9995 A
# Frame:   394, Time: 3940.000 ps
# Rgyr: 35.7262 A
# Frame:   395, Time: 3950.000 ps
# Rgyr: 35.9305 A
# Frame:   396, Time: 3960.000 ps
# Rgyr: 36.2928 A
# Frame:   397, Time: 3970.000 ps
# Rgyr: 36.4058 A
# Frame:   398, Time: 3980.000 ps
# Rgyr: 36.3992 A
# Frame:   399, Time: 3990.000 ps
# Rgyr: 36.3368 A
# Frame:   400, Time: 4000.000 ps
# Rgyr: 36.4885 A
# Frame:   401, Time: 4010.000 ps
# Rgyr: 36.2225 A
# Frame:   402, Time: 4020.000 ps
# Rgyr: 36.0746 A
# Frame:   403, Time: 4030.000 ps
# Rgyr: 35.7299 A
# Frame:   404, Time: 4040.000 ps
# Rgyr: 35.4527 A
# Frame:   405, Time: 4050.000 ps
# Rgyr: 35.7917 A
# Frame:   406, Time: 4060.000 ps
# Rgyr: 35.9215 A
# Frame:   407, Time: 4070.000 ps
# Rgyr: 35.9042 A
# Frame:   408, Time: 4080.000 ps
# Rgyr: 35.5473 A
# Frame:   409, Time: 4090.000 ps
# Rgyr: 35.6884 A
# Frame:   410, Time: 4100.000 ps
# Rgyr: 35.679 A
# Frame:   411, Time: 4110.000 ps
# Rgyr: 35.6456 A
# Frame:   412, Time: 4120.000 ps
# Rgyr: 35.5219 A
# Frame:   413, Time: 4130.000 ps
# Rgyr: 35.2736 A
# Frame:   414, Time: 4140.000 ps
# Rgyr: 35.2073 A
# Frame:   415, Time: 4150.000 ps
# Rgyr: 34.9937 A
# Frame:   416, Time: 4160.000 ps
# Rgyr: 34.8783 A
# Frame:   417, Time: 4170.000 ps
# Rgyr: 35.2192 A
# Frame:   418, Time: 4180.000 ps
# Rgyr: 35.2734 A
# Frame:   419, Time: 4190.000 ps
# Rgyr: 35.4663 A
# Frame:   420, Time: 4200.000 ps
# Rgyr: 35.5484 A
# Frame:   421, Time: 4210.000 ps
# Rgyr: 35.6994 A
# Frame:   422, Time: 4220.000 ps
# Rgyr: 35.6817 A
# Frame:   423, Time: 4230.000 ps
# Rgyr: 35.3621 A
# Frame:   424, Time: 4240.000 ps
# Rgyr: 35.1088 A
# Frame:   425, Time: 4250.000 ps
# Rgyr: 34.9613 A
# Frame:   426, Time: 4260.000 ps
# Rgyr: 35.0714 A
# Frame:   427, Time: 4270.000 ps
# Rgyr: 34.4834 A
# Frame:   428, Time: 4280.000 ps
# Rgyr: 34.3921 A
# Frame:   429, Time: 4290.000 ps
# Rgyr: 34.3813 A
# Frame:   430, Time: 4300.000 ps
# Rgyr: 34.3415 A
# Frame:   431, Time: 4310.000 ps
# Rgyr: 34.4081 A
# Frame:   432, Time: 4320.000 ps
# Rgyr: 34.6028 A
# Frame:   433, Time: 4330.000 ps
# Rgyr: 34.5161 A
# Frame:   434, Time: 4340.000 ps
# Rgyr: 34.3744 A
# Frame:   435, Time: 4350.000 ps
# Rgyr: 34.4718 A
# Frame:   436, Time: 4360.000 ps
# Rgyr: 34.6559 A
# Frame:   437, Time: 4370.000 ps
# Rgyr: 34.68 A
# Frame:   438, Time: 4380.000 ps
# Rgyr: 34.3466 A
# Frame:   439, Time: 4390.000 ps
# Rgyr: 34.6318 A
# Frame:   440, Time: 4400.000 ps
# Rgyr: 34.9529 A
# Frame:   441, Time: 4410.000 ps
# Rgyr: 34.5705 A
# Frame:   442, Time: 4420.000 ps
# Rgyr: 34.8797 A
# Frame:   443, Time: 4430.000 ps
# Rgyr: 35.1289 A
# Frame:   444, Time: 4440.000 ps
# Rgyr: 35.0676 A
# Frame:   445, Time: 4450.000 ps
# Rgyr: 34.955 A
# Frame:   446, Time: 4460.000 ps
# Rgyr: 34.6329 A
# Frame:   447, Time: 4470.000 ps
# Rgyr: 34.7372 A
# Frame:   448, Time: 4480.000 ps
# Rgyr: 34.6761 A
# Frame:   449, Time: 4490.000 ps
# Rgyr: 34.5494 A
# Frame:   450, Time: 4500.000 ps
# Rgyr: 34.5726 A
# Frame:   451, Time: 4510.000 ps
# Rgyr: 35.0026 A
# Frame:   452, Time: 4520.000 ps
# Rgyr: 34.8124 A
# Frame:   453, Time: 4530.000 ps
# Rgyr: 35.1296 A
# Frame:   454, Time: 4540.000 ps
# Rgyr: 35.218 A
# Frame:   455, Time: 4550.000 ps
# Rgyr: 34.8145 A
# Frame:   456, Time: 4560.000 ps
# Rgyr: 34.6939 A
# Frame:   457, Time: 4570.000 ps
# Rgyr: 34.6988 A
# Frame:   458, Time: 4580.000 ps
# Rgyr: 34.429 A
# Frame:   459, Time: 4590.000 ps
# Rgyr: 34.0417 A
# Frame:   460, Time: 4600.000 ps
# Rgyr: 33.9808 A
# Frame:   461, Time: 4610.000 ps
# Rgyr: 34.0834 A
# Frame:   462, Time: 4620.000 ps
# Rgyr: 34.1271 A
# Frame:   463, Time: 4630.000 ps
# Rgyr: 34.2783 A
# Frame:   464, Time: 4640.000 ps
# Rgyr: 34.6307 A
# Frame:   465, Time: 4650.000 ps
# Rgyr: 34.5528 A
# Frame:   466, Time: 4660.000 ps
# Rgyr: 34.5611 A
# Frame:   467, Time: 4670.000 ps
# Rgyr: 34.6678 A
# Frame:   468, Time: 4680.000 ps
# Rgyr: 34.5072 A
# Frame:   469, Time: 4690.000 ps
# Rgyr: 34.5414 A
# Frame:   470, Time: 4700.000 ps
# Rgyr: 34.4944 A
# Frame:   471, Time: 4710.000 ps
# Rgyr: 34.0403 A
# Frame:   472, Time: 4720.000 ps
# Rgyr: 33.6547 A
# Frame:   473, Time: 4730.000 ps
# Rgyr: 33.2623 A
# Frame:   474, Time: 4740.000 ps
# Rgyr: 33.2586 A
# Frame:   475, Time: 4750.000 ps
# Rgyr: 33.2125 A
# Frame:   476, Time: 4760.000 ps
# Rgyr: 33.2744 A
# Frame:   477, Time: 4770.000 ps
# Rgyr: 33.2879 A
# Frame:   478, Time: 4780.000 ps
# Rgyr: 33.0868 A
# Frame:   479, Time: 4790.000 ps
# Rgyr: 33.3963 A
# Frame:   480, Time: 4800.000 ps
# Rgyr: 33.1606 A
# Frame:   481, Time: 4810.000 ps
# Rgyr: 33.109 A
# Frame:   482, Time: 4820.000 ps
# Rgyr: 33.3418 A
# Frame:   483, Time: 4830.000 ps
# Rgyr: 32.9863 A
# Frame:   484, Time: 4840.000 ps
# Rgyr: 32.916 A
# Frame:   485, Time: 4850.000 ps
# Rgyr: 32.7037 A
# Frame:   486, Time: 4860.000 ps
# Rgyr: 32.6855 A
# Frame:   487, Time: 4870.000 ps
# Rgyr: 32.8861 A
# Frame:   488, Time: 4880.000 ps
# Rgyr: 32.6476 A
# Frame:   489, Time: 4890.000 ps
# Rgyr: 32.6626 A
# Frame:   490, Time: 4900.000 ps
# Rgyr: 32.9435 A
# Frame:   491, Time: 4910.000 ps
# Rgyr: 32.9364 A
# Frame:   492, Time: 4920.000 ps
# Rgyr: 32.7576 A
# Frame:   493, Time: 4930.000 ps
# Rgyr: 32.8055 A
# Frame:   494, Time: 4940.000 ps
# Rgyr: 32.5969 A
# Frame:   495, Time: 4950.000 ps
# Rgyr: 32.5807 A
# Frame:   496, Time: 4960.000 ps
# Rgyr: 32.4505 A
# Frame:   497, Time: 4970.000 ps
# Rgyr: 32.0969 A
# Frame:   498, Time: 4980.000 ps
# Rgyr: 31.8863 A
# Frame:   499, Time: 4990.000 ps
# Rgyr: 31.8832 A
# Frame:   500, Time: 5000.000 ps
# Rgyr: 31.8447 A
# Frame:   501, Time: 5010.000 ps
# Rgyr: 31.7706 A
# Frame:   502, Time: 5020.000 ps
# Rgyr: 31.9771 A
# Frame:   503, Time: 5030.000 ps
# Rgyr: 31.9568 A
# Frame:   504, Time: 5040.000 ps
# Rgyr: 32.1249 A
# Frame:   505, Time: 5050.000 ps
# Rgyr: 31.9122 A
# Frame:   506, Time: 5060.000 ps
# Rgyr: 31.7086 A
# Frame:   507, Time: 5070.000 ps
# Rgyr: 31.6162 A
# Frame:   508, Time: 5080.000 ps
# Rgyr: 31.8173 A
# Frame:   509, Time: 5090.000 ps
# Rgyr: 32.0125 A
# Frame:   510, Time: 5100.000 ps
# Rgyr: 32.2731 A
# Frame:   511, Time: 5110.000 ps
# Rgyr: 32.6379 A
# Frame:   512, Time: 5120.000 ps
# Rgyr: 32.751 A
# Frame:   513, Time: 5130.000 ps
# Rgyr: 32.5541 A
# Frame:   514, Time: 5140.000 ps
# Rgyr: 32.3403 A
# Frame:   515, Time: 5150.000 ps
# Rgyr: 32.4655 A
# Frame:   516, Time: 5160.000 ps
# Rgyr: 32.6216 A
# Frame:   517, Time: 5170.000 ps
# Rgyr: 32.7669 A
# Frame:   518, Time: 5180.000 ps
# Rgyr: 32.5672 A
# Frame:   519, Time: 5190.000 ps
# Rgyr: 32.6719 A
# Frame:   520, Time: 5200.000 ps
# Rgyr: 32.6817 A
# Frame:   521, Time: 5210.000 ps
# Rgyr: 32.5662 A
# Frame:   522, Time: 5220.000 ps
# Rgyr: 32.6941 A
# Frame:   523, Time: 5230.000 ps
# Rgyr: 32.6577 A
# Frame:   524, Time: 5240.000 ps
# Rgyr: 32.3741 A
# Frame:   525, Time: 5250.000 ps
# Rgyr: 32.2963 A
# Frame:   526, Time: 5260.000 ps
# Rgyr: 32.6342 A
# Frame:   527, Time: 5270.000 ps
# Rgyr: 32.582 A
# Frame:   528, Time: 5280.000 ps
# Rgyr: 32.4316 A
# Frame:   529, Time: 5290.000 ps
# Rgyr: 32.4985 A
# Frame:   530, Time: 5300.000 ps
# Rgyr: 32.2887 A
# Frame:   531, Time: 5310.000 ps
# Rgyr: 32.2689 A
# Frame:   532, Time: 5320.000 ps
# Rgyr: 32.0189 A
# Frame:   533, Time: 5330.000 ps
# Rgyr: 31.8641 A
# Frame:   534, Time: 5340.000 ps
# Rgyr: 31.9128 A
# Frame:   535, Time: 5350.000 ps
# Rgyr: 31.9711 A
# Frame:   536, Time: 5360.000 ps
# Rgyr: 31.8271 A
# Frame:   537, Time: 5370.000 ps
# Rgyr: 31.7886 A
# Frame:   538, Time: 5380.000 ps
# Rgyr: 31.9348 A
# Frame:   539, Time: 5390.000 ps
# Rgyr: 31.6933 A
# Frame:   540, Time: 5400.000 ps
# Rgyr: 31.8137 A
# Frame:   541, Time: 5410.000 ps
# Rgyr: 31.771 A
# Frame:   542, Time: 5420.000 ps
# Rgyr: 31.5161 A
# Frame:   543, Time: 5430.000 ps
# Rgyr: 31.2753 A
# Frame:   544, Time: 5440.000 ps
# Rgyr: 31.3745 A
# Frame:   545, Time: 5450.000 ps
# Rgyr: 31.2348 A
# Frame:   546, Time: 5460.000 ps
# Rgyr: 31.2823 A
# Frame:   547, Time: 5470.000 ps
# Rgyr: 31.2343 A
# Frame:   548, Time: 5480.000 ps
# Rgyr: 31.2225 A
# Frame:   549, Time: 5490.000 ps
# Rgyr: 31.1085 A
# Frame:   550, Time: 5500.000 ps
# Rgyr: 30.7584 A
# Frame:   551, Time: 5510.000 ps
# Rgyr: 30.4889 A
# Frame:   552, Time: 5520.000 ps
# Rgyr: 30.3298 A
# Frame:   553, Time: 5530.000 ps
# Rgyr: 30.4527 A
# Frame:   554, Time: 5540.000 ps
# Rgyr: 30.5779 A
# Frame:   555, Time: 5550.000 ps
# Rgyr: 30.4407 A
# Frame:   556, Time: 5560.000 ps
# Rgyr: 30.2022 A
# Frame:   557, Time: 5570.000 ps
# Rgyr: 30.2272 A
# Frame:   558, Time: 5580.000 ps
# Rgyr: 29.9872 A
# Frame:   559, Time: 5590.000 ps
# Rgyr: 30.1186 A
# Frame:   560, Time: 5600.000 ps
# Rgyr: 30.0502 A
# Frame:   561, Time: 5610.000 ps
# Rgyr: 30.1357 A
# Frame:   562, Time: 5620.000 ps
# Rgyr: 30.0256 A
# Frame:   563, Time: 5630.000 ps
# Rgyr: 30.4536 A
# Frame:   564, Time: 5640.000 ps
# Rgyr: 29.9935 A
# Frame:   565, Time: 5650.000 ps
# Rgyr: 30.5519 A
# Frame:   566, Time: 5660.000 ps
# Rgyr: 30.7391 A
# Frame:   567, Time: 5670.000 ps
# Rgyr: 30.9366 A
# Frame:   568, Time: 5680.000 ps
# Rgyr: 31.1165 A
# Frame:   569, Time: 5690.000 ps
# Rgyr: 30.8413 A
# Frame:   570, Time: 5700.000 ps
# Rgyr: 31.0122 A
# Frame:   571, Time: 5710.000 ps
# Rgyr: 31.1193 A
# Frame:   572, Time: 5720.000 ps
# Rgyr: 31.0705 A
# Frame:   573, Time: 5730.000 ps
# Rgyr: 31.1374 A
# Frame:   574, Time: 5740.000 ps
# Rgyr: 31.1777 A
# Frame:   575, Time: 5750.000 ps
# Rgyr: 31.3058 A
# Frame:   576, Time: 5760.000 ps
# Rgyr: 30.8888 A
# Frame:   577, Time: 5770.000 ps
# Rgyr: 30.8467 A
# Frame:   578, Time: 5780.000 ps
# Rgyr: 30.8386 A
# Frame:   579, Time: 5790.000 ps
# Rgyr: 30.972 A
# Frame:   580, Time: 5800.000 ps
# Rgyr: 31.1978 A
# Frame:   581, Time: 5810.000 ps
# Rgyr: 30.9256 A
# Frame:   582, Time: 5820.000 ps
# Rgyr: 30.8753 A
# Frame:   583, Time: 5830.000 ps
# Rgyr: 31.0284 A
# Frame:   584, Time: 5840.000 ps
# Rgyr: 31.1248 A
# Frame:   585, Time: 5850.000 ps
# Rgyr: 31.2048 A
# Frame:   586, Time: 5860.000 ps
# Rgyr: 31.4747 A
# Frame:   587, Time: 5870.000 ps
# Rgyr: 31.1441 A
# Frame:   588, Time: 5880.000 ps
# Rgyr: 31.5018 A
# Frame:   589, Time: 5890.000 ps
# Rgyr: 31.4997 A
# Frame:   590, Time: 5900.000 ps
# Rgyr: 32.1694 A
# Frame:   591, Time: 5910.000 ps
# Rgyr: 32.2925 A
# Frame:   592, Time: 5920.000 ps
# Rgyr: 32.5822 A
# Frame:   593, Time: 5930.000 ps
# Rgyr: 32.3117 A
# Frame:   594, Time: 5940.000 ps
# Rgyr: 32.0848 A
# Frame:   595, Time: 5950.000 ps
# Rgyr: 32.2269 A
# Frame:   596, Time: 5960.000 ps
# Rgyr: 32.1727 A
# Frame:   597, Time: 5970.000 ps
# Rgyr: 32.5053 A
# Frame:   598, Time: 5980.000 ps
# Rgyr: 32.5388 A
# Frame:   599, Time: 5990.000 ps
# Rgyr: 32.3142 A
# Frame:   600, Time: 6000.000 ps
# Rgyr: 32.2708 A
# Frame:   601, Time: 6010.000 ps
# Rgyr: 32.0817 A
# Frame:   602, Time: 6020.000 ps
# Rgyr: 31.9834 A
# Frame:   603, Time: 6030.000 ps
# Rgyr: 32.1521 A
# Frame:   604, Time: 6040.000 ps
# Rgyr: 31.9737 A
# Frame:   605, Time: 6050.000 ps
# Rgyr: 32.2544 A
# Frame:   606, Time: 6060.000 ps
# Rgyr: 32.3878 A
# Frame:   607, Time: 6070.000 ps
# Rgyr: 32.4226 A
# Frame:   608, Time: 6080.000 ps
# Rgyr: 32.0523 A
# Frame:   609, Time: 6090.000 ps
# Rgyr: 32.5777 A
# Frame:   610, Time: 6100.000 ps
# Rgyr: 32.7683 A
# Frame:   611, Time: 6110.000 ps
# Rgyr: 32.5772 A
# Frame:   612, Time: 6120.000 ps
# Rgyr: 32.3883 A
# Frame:   613, Time: 6130.000 ps
# Rgyr: 32.2231 A
# Frame:   614, Time: 6140.000 ps
# Rgyr: 32.2215 A
# Frame:   615, Time: 6150.000 ps
# Rgyr: 32.4318 A
# Frame:   616, Time: 6160.000 ps
# Rgyr: 32.4306 A
# Frame:   617, Time: 6170.000 ps
# Rgyr: 32.5142 A
# Frame:   618, Time: 6180.000 ps
# Rgyr: 32.6907 A
# Frame:   619, Time: 6190.000 ps
# Rgyr: 32.366 A
# Frame:   620, Time: 6200.000 ps
# Rgyr: 32.4494 A
# Frame:   621, Time: 6210.000 ps
# Rgyr: 32.6316 A
# Frame:   622, Time: 6220.000 ps
# Rgyr: 32.7857 A
# Frame:   623, Time: 6230.000 ps
# Rgyr: 32.9738 A
# Frame:   624, Time: 6240.000 ps
# Rgyr: 33.0924 A
# Frame:   625, Time: 6250.000 ps
# Rgyr: 33.2088 A
# Frame:   626, Time: 6260.000 ps
# Rgyr: 33.1997 A
# Frame:   627, Time: 6270.000 ps
# Rgyr: 33.4256 A
# Frame:   628, Time: 6280.000 ps
# Rgyr: 33.3613 A
# Frame:   629, Time: 6290.000 ps
# Rgyr: 33.3409 A
# Frame:   630, Time: 6300.000 ps
# Rgyr: 33.2178 A
# Frame:   631, Time: 6310.000 ps
# Rgyr: 33.3137 A
# Frame:   632, Time: 6320.000 ps
# Rgyr: 33.3287 A
# Frame:   633, Time: 6330.000 ps
# Rgyr: 33.1959 A
# Frame:   634, Time: 6340.000 ps
# Rgyr: 32.787 A
# Frame:   635, Time: 6350.000 ps
# Rgyr: 33.2085 A
# Frame:   636, Time: 6360.000 ps
# Rgyr: 33.0562 A
# Frame:   637, Time: 6370.000 ps
# Rgyr: 33.0635 A
# Frame:   638, Time: 6380.000 ps
# Rgyr: 33.1356 A
# Frame:   639, Time: 6390.000 ps
# Rgyr: 33.0615 A
# Frame:   640, Time: 6400.000 ps
# Rgyr: 32.5754 A
# Frame:   641, Time: 6410.000 ps
# Rgyr: 32.8276 A
# Frame:   642, Time: 6420.000 ps
# Rgyr: 33.1378 A
# Frame:   643, Time: 6430.000 ps
# Rgyr: 33.2275 A
# Frame:   644, Time: 6440.000 ps
# Rgyr: 33.78 A
# Frame:   645, Time: 6450.000 ps
# Rgyr: 33.6562 A
# Frame:   646, Time: 6460.000 ps
# Rgyr: 33.4939 A
# Frame:   647, Time: 6470.000 ps
# Rgyr: 33.474 A
# Frame:   648, Time: 6480.000 ps
# Rgyr: 33.6037 A
# Frame:   649, Time: 6490.000 ps
# Rgyr: 33.7375 A
# Frame:   650, Time: 6500.000 ps
# Rgyr: 33.7779 A
# Frame:   651, Time: 6510.000 ps
# Rgyr: 33.3373 A
# Frame:   652, Time: 6520.000 ps
# Rgyr: 33.8505 A
# Frame:   653, Time: 6530.000 ps
# Rgyr: 34.1429 A
# Frame:   654, Time: 6540.000 ps
# Rgyr: 33.7622 A
# Frame:   655, Time: 6550.000 ps
# Rgyr: 33.8622 A
# Frame:   656, Time: 6560.000 ps
# Rgyr: 33.6476 A
# Frame:   657, Time: 6570.000 ps
# Rgyr: 33.3614 A
# Frame:   658, Time: 6580.000 ps
# Rgyr: 33.4256 A
# Frame:   659, Time: 6590.000 ps
# Rgyr: 33.5645 A
# Frame:   660, Time: 6600.000 ps
# Rgyr: 33.1914 A
# Frame:   661, Time: 6610.000 ps
# Rgyr: 33.3852 A
# Frame:   662, Time: 6620.000 ps
# Rgyr: 33.4385 A
# Frame:   663, Time: 6630.000 ps
# Rgyr: 33.8122 A
# Frame:   664, Time: 6640.000 ps
# Rgyr: 33.3635 A
# Frame:   665, Time: 6650.000 ps
# Rgyr: 33.8569 A
# Frame:   666, Time: 6660.000 ps
# Rgyr: 33.6036 A
# Frame:   667, Time: 6670.000 ps
# Rgyr: 33.5891 A
# Frame:   668, Time: 6680.000 ps
# Rgyr: 33.4177 A
# Frame:   669, Time: 6690.000 ps
# Rgyr: 33.636 A
# Frame:   670, Time: 6700.000 ps
# Rgyr: 33.4146 A
# Frame:   671, Time: 6710.000 ps
# Rgyr: 33.6587 A
# Frame:   672, Time: 6720.000 ps
# Rgyr: 33.589 A
# Frame:   673, Time: 6730.000 ps
# Rgyr: 33.6102 A
# Frame:   674, Time: 6740.000 ps
# Rgyr: 33.6141 A
# Frame:   675, Time: 6750.000 ps
# Rgyr: 33.4705 A
# Frame:   676, Time: 6760.000 ps
# Rgyr: 33.5131 A
# Frame:   677, Time: 6770.000 ps
# Rgyr: 33.5025 A
# Frame:   678, Time: 6780.000 ps
# Rgyr: 33.4042 A
# Frame:   679, Time: 6790.000 ps
# Rgyr: 33.2912 A
# Frame:   680, Time: 6800.000 ps
# Rgyr: 33.4377 A
# Frame:   681, Time: 6810.000 ps
# Rgyr: 33.6501 A
# Frame:   682, Time: 6820.000 ps
# Rgyr: 33.5103 A
# Frame:   683, Time: 6830.000 ps
# Rgyr: 33.3822 A
# Frame:   684, Time: 6840.000 ps
# Rgyr: 33.1939 A
# Frame:   685, Time: 6850.000 ps
# Rgyr: 33.3619 A
# Frame:   686, Time: 6860.000 ps
# Rgyr: 33.6363 A
# Frame:   687, Time: 6870.000 ps
# Rgyr: 33.6074 A
# Frame:   688, Time: 6880.000 ps
# Rgyr: 33.8278 A
# Frame:   689, Time: 6890.000 ps
# Rgyr: 33.7033 A
# Frame:   690, Time: 6900.000 ps
# Rgyr: 33.9535 A
# Frame:   691, Time: 6910.000 ps
# Rgyr: 34.0453 A
# Frame:   692, Time: 6920.000 ps
# Rgyr: 33.9666 A
# Frame:   693, Time: 6930.000 ps
# Rgyr: 33.9039 A
# Frame:   694, Time: 6940.000 ps
# Rgyr: 33.8976 A
# Frame:   695, Time: 6950.000 ps
# Rgyr: 34.1152 A
# Frame:   696, Time: 6960.000 ps
# Rgyr: 34.1873 A
# Frame:   697, Time: 6970.000 ps
# Rgyr: 34.255 A
# Frame:   698, Time: 6980.000 ps
# Rgyr: 34.0507 A
# Frame:   699, Time: 6990.000 ps
# Rgyr: 34.3707 A
# Frame:   700, Time: 7000.000 ps
# Rgyr: 34.5251 A
# Frame:   701, Time: 7010.000 ps
# Rgyr: 34.2752 A
# Frame:   702, Time: 7020.000 ps
# Rgyr: 34.3636 A
# Frame:   703, Time: 7030.000 ps
# Rgyr: 34.3454 A
# Frame:   704, Time: 7040.000 ps
# Rgyr: 34.3462 A
# Frame:   705, Time: 7050.000 ps
# Rgyr: 34.2329 A
# Frame:   706, Time: 7060.000 ps
# Rgyr: 34.3431 A
# Frame:   707, Time: 7070.000 ps
# Rgyr: 34.1597 A
# Frame:   708, Time: 7080.000 ps
# Rgyr: 34.4366 A
# Frame:   709, Time: 7090.000 ps
# Rgyr: 34.2669 A
# Frame:   710, Time: 7100.000 ps
# Rgyr: 34.3658 A
# Frame:   711, Time: 7110.000 ps
# Rgyr: 34.7235 A
# Frame:   712, Time: 7120.000 ps
# Rgyr: 34.61 A
# Frame:   713, Time: 7130.000 ps
# Rgyr: 34.9613 A
# Frame:   714, Time: 7140.000 ps
# Rgyr: 34.6776 A
# Frame:   715, Time: 7150.000 ps
# Rgyr: 34.7526 A
# Frame:   716, Time: 7160.000 ps
# Rgyr: 34.759 A
# Frame:   717, Time: 7170.000 ps
# Rgyr: 34.8262 A
# Frame:   718, Time: 7180.000 ps
# Rgyr: 34.6131 A
# Frame:   719, Time: 7190.000 ps
# Rgyr: 34.5012 A
# Frame:   720, Time: 7200.000 ps
# Rgyr: 34.6528 A
# Frame:   721, Time: 7210.000 ps
# Rgyr: 34.6807 A
# Frame:   722, Time: 7220.000 ps
# Rgyr: 35.2104 A
# Frame:   723, Time: 7230.000 ps
# Rgyr: 35.2168 A
# Frame:   724, Time: 7240.000 ps
# Rgyr: 34.8756 A
# Frame:   725, Time: 7250.000 ps
# Rgyr: 35.1058 A
# Frame:   726, Time: 7260.000 ps
# Rgyr: 35.0204 A
# Frame:   727, Time: 7270.000 ps
# Rgyr: 35.2955 A
# Frame:   728, Time: 7280.000 ps
# Rgyr: 35.326 A
# Frame:   729, Time: 7290.000 ps
# Rgyr: 35.4283 A
# Frame:   730, Time: 7300.000 ps
# Rgyr: 35.5371 A
# Frame:   731, Time: 7310.000 ps
# Rgyr: 35.7413 A
# Frame:   732, Time: 7320.000 ps
# Rgyr: 35.8659 A
# Frame:   733, Time: 7330.000 ps
# Rgyr: 36.1472 A
# Frame:   734, Time: 7340.000 ps
# Rgyr: 35.9384 A
# Frame:   735, Time: 7350.000 ps
# Rgyr: 36.0685 A
# Frame:   736, Time: 7360.000 ps
# Rgyr: 36.2275 A
# Frame:   737, Time: 7370.000 ps
# Rgyr: 36.3842 A
# Frame:   738, Time: 7380.000 ps
# Rgyr: 36.083 A
# Frame:   739, Time: 7390.000 ps
# Rgyr: 35.9869 A
# Frame:   740, Time: 7400.000 ps
# Rgyr: 36.02 A
# Frame:   741, Time: 7410.000 ps
# Rgyr: 36.352 A
# Frame:   742, Time: 7420.000 ps
# Rgyr: 36.0035 A
# Frame:   743, Time: 7430.000 ps
# Rgyr: 36.0442 A
# Frame:   744, Time: 7440.000 ps
# Rgyr: 36.0059 A
# Frame:   745, Time: 7450.000 ps
# Rgyr: 35.9594 A
# Frame:   746, Time: 7460.000 ps
# Rgyr: 35.9208 A
# Frame:   747, Time: 7470.000 ps
# Rgyr: 35.8502 A
# Frame:   748, Time: 7480.000 ps
# Rgyr: 35.9402 A
# Frame:   749, Time: 7490.000 ps
# Rgyr: 35.9363 A
# Frame:   750, Time: 7500.000 ps
# Rgyr: 35.6622 A
# Frame:   751, Time: 7510.000 ps
# Rgyr: 35.785 A
# Frame:   752, Time: 7520.000 ps
# Rgyr: 35.6529 A
# Frame:   753, Time: 7530.000 ps
# Rgyr: 35.5658 A
# Frame:   754, Time: 7540.000 ps
# Rgyr: 35.4783 A
# Frame:   755, Time: 7550.000 ps
# Rgyr: 35.6411 A
# Frame:   756, Time: 7560.000 ps
# Rgyr: 35.916 A
# Frame:   757, Time: 7570.000 ps
# Rgyr: 35.902 A
# Frame:   758, Time: 7580.000 ps
# Rgyr: 35.6122 A
# Frame:   759, Time: 7590.000 ps
# Rgyr: 35.4223 A
# Frame:   760, Time: 7600.000 ps
# Rgyr: 35.1599 A
# Frame:   761, Time: 7610.000 ps
# Rgyr: 35.7254 A
# Frame:   762, Time: 7620.000 ps
# Rgyr: 35.6437 A
# Frame:   763, Time: 7630.000 ps
# Rgyr: 35.4192 A
# Frame:   764, Time: 7640.000 ps
# Rgyr: 35.367 A
# Frame:   765, Time: 7650.000 ps
# Rgyr: 35.1238 A
# Frame:   766, Time: 7660.000 ps
# Rgyr: 35.2698 A
# Frame:   767, Time: 7670.000 ps
# Rgyr: 35.527 A
# Frame:   768, Time: 7680.000 ps
# Rgyr: 35.3002 A
# Frame:   769, Time: 7690.000 ps
# Rgyr: 35.105 A
# Frame:   770, Time: 7700.000 ps
# Rgyr: 35.2436 A
# Frame:   771, Time: 7710.000 ps
# Rgyr: 35.3148 A
# Frame:   772, Time: 7720.000 ps
# Rgyr: 35.4016 A
# Frame:   773, Time: 7730.000 ps
# Rgyr: 35.0907 A
# Frame:   774, Time: 7740.000 ps
# Rgyr: 35.124 A
# Frame:   775, Time: 7750.000 ps
# Rgyr: 35.1996 A
# Frame:   776, Time: 7760.000 ps
# Rgyr: 35.3782 A
# Frame:   777, Time: 7770.000 ps
# Rgyr: 35.073 A
# Frame:   778, Time: 7780.000 ps
# Rgyr: 34.8662 A
# Frame:   779, Time: 7790.000 ps
# Rgyr: 34.8809 A
# Frame:   780, Time: 7800.000 ps
# Rgyr: 34.7716 A
# Frame:   781, Time: 7810.000 ps
# Rgyr: 34.8095 A
# Frame:   782, Time: 7820.000 ps
# Rgyr: 34.9315 A
# Frame:   783, Time: 7830.000 ps
# Rgyr: 35.0727 A
# Frame:   784, Time: 7840.000 ps
# Rgyr: 35.0989 A
# Frame:   785, Time: 7850.000 ps
# Rgyr: 35.1158 A
# Frame:   786, Time: 7860.000 ps
# Rgyr: 34.7284 A
# Frame:   787, Time: 7870.000 ps
# Rgyr: 34.5753 A
# Frame:   788, Time: 7880.000 ps
# Rgyr: 34.6299 A
# Frame:   789, Time: 7890.000 ps
# Rgyr: 34.3623 A
# Frame:   790, Time: 7900.000 ps
# Rgyr: 34.0503 A
# Frame:   791, Time: 7910.000 ps
# Rgyr: 33.9004 A
# Frame:   792, Time: 7920.000 ps
# Rgyr: 33.9693 A
# Frame:   793, Time: 7930.000 ps
# Rgyr: 34.3886 A
# Frame:   794, Time: 7940.000 ps
# Rgyr: 34.3547 A
# Frame:   795, Time: 7950.000 ps
# Rgyr: 34.8216 A
# Frame:   796, Time: 7960.000 ps
# Rgyr: 34.6529 A
# Frame:   797, Time: 7970.000 ps
# Rgyr: 34.6433 A
# Frame:   798, Time: 7980.000 ps
# Rgyr: 34.5906 A
# Frame:   799, Time: 7990.000 ps
# Rgyr: 34.6478 A
# Frame:   800, Time: 8000.000 ps
# Rgyr: 34.8732 A
# Frame:   801, Time: 8010.000 ps
# Rgyr: 34.6996 A
# Frame:   802, Time: 8020.000 ps
# Rgyr: 34.8276 A
# Frame:   803, Time: 8030.000 ps
# Rgyr: 34.5142 A
# Frame:   804, Time: 8040.000 ps
# Rgyr: 34.5121 A
# Frame:   805, Time: 8050.000 ps
# Rgyr: 34.7594 A
# Frame:   806, Time: 8060.000 ps
# Rgyr: 34.5609 A
# Frame:   807, Time: 8070.000 ps
# Rgyr: 34.9472 A
# Frame:   808, Time: 8080.000 ps
# Rgyr: 35.1084 A
# Frame:   809, Time: 8090.000 ps
# Rgyr: 34.9277 A
# Frame:   810, Time: 8100.000 ps
# Rgyr: 34.7822 A
# Frame:   811, Time: 8110.000 ps
# Rgyr: 34.9757 A
# Frame:   812, Time: 8120.000 ps
# Rgyr: 34.9226 A
# Frame:   813, Time: 8130.000 ps
# Rgyr: 34.5018 A
# Frame:   814, Time: 8140.000 ps
# Rgyr: 34.6889 A
# Frame:   815, Time: 8150.000 ps
# Rgyr: 34.7427 A
# Frame:   816, Time: 8160.000 ps
# Rgyr: 34.7439 A
# Frame:   817, Time: 8170.000 ps
# Rgyr: 34.633 A
# Frame:   818, Time: 8180.000 ps
# Rgyr: 34.6005 A
# Frame:   819, Time: 8190.000 ps
# Rgyr: 34.6011 A
# Frame:   820, Time: 8200.000 ps
# Rgyr: 34.8319 A
# Frame:   821, Time: 8210.000 ps
# Rgyr: 35.3128 A
# Frame:   822, Time: 8220.000 ps
# Rgyr: 35.3723 A
# Frame:   823, Time: 8230.000 ps
# Rgyr: 35.2274 A
# Frame:   824, Time: 8240.000 ps
# Rgyr: 35.3008 A
# Frame:   825, Time: 8250.000 ps
# Rgyr: 35.1117 A
# Frame:   826, Time: 8260.000 ps
# Rgyr: 34.9381 A
# Frame:   827, Time: 8270.000 ps
# Rgyr: 34.936 A
# Frame:   828, Time: 8280.000 ps
# Rgyr: 35.2737 A
# Frame:   829, Time: 8290.000 ps
# Rgyr: 35.3829 A
# Frame:   830, Time: 8300.000 ps
# Rgyr: 35.3646 A
# Frame:   831, Time: 8310.000 ps
# Rgyr: 35.6218 A
# Frame:   832, Time: 8320.000 ps
# Rgyr: 35.7347 A
# Frame:   833, Time: 8330.000 ps
# Rgyr: 35.4751 A
# Frame:   834, Time: 8340.000 ps
# Rgyr: 35.2877 A
# Frame:   835, Time: 8350.000 ps
# Rgyr: 35.3731 A
# Frame:   836, Time: 8360.000 ps
# Rgyr: 35.2079 A
# Frame:   837, Time: 8370.000 ps
# Rgyr: 35.3039 A
# Frame:   838, Time: 8380.000 ps
# Rgyr: 35.1895 A
# Frame:   839, Time: 8390.000 ps
# Rgyr: 35.1607 A
# Frame:   840, Time: 8400.000 ps
# Rgyr: 34.9795 A
# Frame:   841, Time: 8410.000 ps
# Rgyr: 34.9562 A
# Frame:   842, Time: 8420.000 ps
# Rgyr: 35.0461 A
# Frame:   843, Time: 8430.000 ps
# Rgyr: 35.1706 A
# Frame:   844, Time: 8440.000 ps
# Rgyr: 34.9411 A
# Frame:   845, Time: 8450.000 ps
# Rgyr: 35.0619 A
# Frame:   846, Time: 8460.000 ps
# Rgyr: 34.6136 A
# Frame:   847, Time: 8470.000 ps
# Rgyr: 34.4904 A
# Frame:   848, Time: 8480.000 ps
# Rgyr: 34.1119 A
# Frame:   849, Time: 8490.000 ps
# Rgyr: 34.3647 A
# Frame:   850, Time: 8500.000 ps
# Rgyr: 34.4754 A
# Frame:   851, Time: 8510.000 ps
# Rgyr: 34.6228 A
# Frame:   852, Time: 8520.000 ps
# Rgyr: 34.4838 A
# Frame:   853, Time: 8530.000 ps
# Rgyr: 34.4679 A
# Frame:   854, Time: 8540.000 ps
# Rgyr: 34.2833 A
# Frame:   855, Time: 8550.000 ps
# Rgyr: 34.071 A
# Frame:   856, Time: 8560.000 ps
# Rgyr: 33.9427 A
# Frame:   857, Time: 8570.000 ps
# Rgyr: 33.7528 A
# Frame:   858, Time: 8580.000 ps
# Rgyr: 34.0218 A
# Frame:   859, Time: 8590.000 ps
# Rgyr: 34.1347 A
# Frame:   860, Time: 8600.000 ps
# Rgyr: 34.5607 A
# Frame:   861, Time: 8610.000 ps
# Rgyr: 34.3964 A
# Frame:   862, Time: 8620.000 ps
# Rgyr: 34.5531 A
# Frame:   863, Time: 8630.000 ps
# Rgyr: 34.9642 A
# Frame:   864, Time: 8640.000 ps
# Rgyr: 34.7681 A
# Frame:   865, Time: 8650.000 ps
# Rgyr: 34.6945 A
# Frame:   866, Time: 8660.000 ps
# Rgyr: 34.9112 A
# Frame:   867, Time: 8670.000 ps
# Rgyr: 34.6897 A
# Frame:   868, Time: 8680.000 ps
# Rgyr: 34.9425 A
# Frame:   869, Time: 8690.000 ps
# Rgyr: 34.7874 A
# Frame:   870, Time: 8700.000 ps
# Rgyr: 34.7854 A
# Frame:   871, Time: 8710.000 ps
# Rgyr: 34.4862 A
# Frame:   872, Time: 8720.000 ps
# Rgyr: 34.2134 A
# Frame:   873, Time: 8730.000 ps
# Rgyr: 34.293 A
# Frame:   874, Time: 8740.000 ps
# Rgyr: 34.302 A
# Frame:   875, Time: 8750.000 ps
# Rgyr: 34.4479 A
# Frame:   876, Time: 8760.000 ps
# Rgyr: 34.2768 A
# Frame:   877, Time: 8770.000 ps
# Rgyr: 34.0573 A
# Frame:   878, Time: 8780.000 ps
# Rgyr: 34.1128 A
# Frame:   879, Time: 8790.000 ps
# Rgyr: 34.0787 A
# Frame:   880, Time: 8800.000 ps
# Rgyr: 34.1777 A
# Frame:   881, Time: 8810.000 ps
# Rgyr: 34.1222 A
# Frame:   882, Time: 8820.000 ps
# Rgyr: 34.3405 A
# Frame:   883, Time: 8830.000 ps
# Rgyr: 34.5392 A
# Frame:   884, Time: 8840.000 ps
# Rgyr: 34.4547 A
# Frame:   885, Time: 8850.000 ps
# Rgyr: 34.4583 A
# Frame:   886, Time: 8860.000 ps
# Rgyr: 34.6713 A
# Frame:   887, Time: 8870.000 ps
# Rgyr: 34.5303 A
# Frame:   888, Time: 8880.000 ps
# Rgyr: 34.5628 A
# Frame:   889, Time: 8890.000 ps
# Rgyr: 34.3096 A
# Frame:   890, Time: 8900.000 ps
# Rgyr: 34.2536 A
# Frame:   891, Time: 8910.000 ps
# Rgyr: 34.2718 A
# Frame:   892, Time: 8920.000 ps
# Rgyr: 34.1792 A
# Frame:   893, Time: 8930.000 ps
# Rgyr: 34.0946 A
# Frame:   894, Time: 8940.000 ps
# Rgyr: 34.2722 A
# Frame:   895, Time: 8950.000 ps
# Rgyr: 34.027 A
# Frame:   896, Time: 8960.000 ps
# Rgyr: 34.0285 A
# Frame:   897, Time: 8970.000 ps
# Rgyr: 34.2036 A
# Frame:   898, Time: 8980.000 ps
# Rgyr: 33.9886 A
# Frame:   899, Time: 8990.000 ps
# Rgyr: 33.847 A
# Frame:   900, Time: 9000.000 ps
# Rgyr: 33.8655 A
# Frame:   901, Time: 9010.000 ps
# Rgyr: 34.0133 A
# Frame:   902, Time: 9020.000 ps
# Rgyr: 34.1734 A
# Frame:   903, Time: 9030.000 ps
# Rgyr: 33.9772 A
# Frame:   904, Time: 9040.000 ps
# Rgyr: 33.9654 A
# Frame:   905, Time: 9050.000 ps
# Rgyr: 34.0978 A
# Frame:   906, Time: 9060.000 ps
# Rgyr: 34.1208 A
# Frame:   907, Time: 9070.000 ps
# Rgyr: 34.1038 A
# Frame:   908, Time: 9080.000 ps
# Rgyr: 33.7085 A
# Frame:   909, Time: 9090.000 ps
# Rgyr: 34.2267 A
# Frame:   910, Time: 9100.000 ps
# Rgyr: 34.2213 A
# Frame:   911, Time: 9110.000 ps
# Rgyr: 34.2581 A
# Frame:   912, Time: 9120.000 ps
# Rgyr: 34.4067 A
# Frame:   913, Time: 9130.000 ps
# Rgyr: 34.6727 A
# Frame:   914, Time: 9140.000 ps
# Rgyr: 34.4757 A
# Frame:   915, Time: 9150.000 ps
# Rgyr: 34.5399 A
# Frame:   916, Time: 9160.000 ps
# Rgyr: 34.2407 A
# Frame:   917, Time: 9170.000 ps
# Rgyr: 34.3044 A
# Frame:   918, Time: 9180.000 ps
# Rgyr: 34.5112 A
# Frame:   919, Time: 9190.000 ps
# Rgyr: 34.338 A
# Frame:   920, Time: 9200.000 ps
# Rgyr: 34.3409 A
# Frame:   921, Time: 9210.000 ps
# Rgyr: 34.2348 A
# Frame:   922, Time: 9220.000 ps
# Rgyr: 34.197 A
# Frame:   923, Time: 9230.000 ps
# Rgyr: 34.0762 A
# Frame:   924, Time: 9240.000 ps
# Rgyr: 34.0967 A
# Frame:   925, Time: 9250.000 ps
# Rgyr: 34.1324 A
# Frame:   926, Time: 9260.000 ps
# Rgyr: 33.7582 A
# Frame:   927, Time: 9270.000 ps
# Rgyr: 33.7752 A
# Frame:   928, Time: 9280.000 ps
# Rgyr: 33.5877 A
# Frame:   929, Time: 9290.000 ps
# Rgyr: 33.1451 A
# Frame:   930, Time: 9300.000 ps
# Rgyr: 32.8423 A
# Frame:   931, Time: 9310.000 ps
# Rgyr: 33.2355 A
# Frame:   932, Time: 9320.000 ps
# Rgyr: 33.3565 A
# Frame:   933, Time: 9330.000 ps
# Rgyr: 33.6364 A
# Frame:   934, Time: 9340.000 ps
# Rgyr: 33.3475 A
# Frame:   935, Time: 9350.000 ps
# Rgyr: 33.4651 A
# Frame:   936, Time: 9360.000 ps
# Rgyr: 33.3455 A
# Frame:   937, Time: 9370.000 ps
# Rgyr: 33.372 A
# Frame:   938, Time: 9380.000 ps
# Rgyr: 33.416 A
# Frame:   939, Time: 9390.000 ps
# Rgyr: 33.6895 A
# Frame:   940, Time: 9400.000 ps
# Rgyr: 33.9064 A
# Frame:   941, Time: 9410.000 ps
# Rgyr: 33.8393 A
# Frame:   942, Time: 9420.000 ps
# Rgyr: 34.1861 A
# Frame:   943, Time: 9430.000 ps
# Rgyr: 34.2157 A
# Frame:   944, Time: 9440.000 ps
# Rgyr: 34.0603 A
# Frame:   945, Time: 9450.000 ps
# Rgyr: 34.0126 A
# Frame:   946, Time: 9460.000 ps
# Rgyr: 34.4427 A
# Frame:   947, Time: 9470.000 ps
# Rgyr: 34.3261 A
# Frame:   948, Time: 9480.000 ps
# Rgyr: 33.832 A
# Frame:   949, Time: 9490.000 ps
# Rgyr: 34.1183 A
# Frame:   950, Time: 9500.000 ps
# Rgyr: 33.6438 A
# Frame:   951, Time: 9510.000 ps
# Rgyr: 33.3158 A
# Frame:   952, Time: 9520.000 ps
# Rgyr: 33.6679 A
# Frame:   953, Time: 9530.000 ps
# Rgyr: 33.5516 A
# Frame:   954, Time: 9540.000 ps
# Rgyr: 33.5056 A
# Frame:   955, Time: 9550.000 ps
# Rgyr: 33.4264 A
# Frame:   956, Time: 9560.000 ps
# Rgyr: 33.2663 A
# Frame:   957, Time: 9570.000 ps
# Rgyr: 33.1765 A
# Frame:   958, Time: 9580.000 ps
# Rgyr: 33.226 A
# Frame:   959, Time: 9590.000 ps
# Rgyr: 33.1042 A
# Frame:   960, Time: 9600.000 ps
# Rgyr: 33.0781 A
# Frame:   961, Time: 9610.000 ps
# Rgyr: 33.2368 A
# Frame:   962, Time: 9620.000 ps
# Rgyr: 33.1349 A
# Frame:   963, Time: 9630.000 ps
# Rgyr: 33.0646 A
# Frame:   964, Time: 9640.000 ps
# Rgyr: 33.1063 A
# Frame:   965, Time: 9650.000 ps
# Rgyr: 33.32 A
# Frame:   966, Time: 9660.000 ps
# Rgyr: 33.5352 A
# Frame:   967, Time: 9670.000 ps
# Rgyr: 33.6717 A
# Frame:   968, Time: 9680.000 ps
# Rgyr: 33.6559 A
# Frame:   969, Time: 9690.000 ps
# Rgyr: 33.6492 A
# Frame:   970, Time: 9700.000 ps
# Rgyr: 33.4614 A
# Frame:   971, Time: 9710.000 ps
# Rgyr: 33.3301 A
# Frame:   972, Time: 9720.000 ps
# Rgyr: 33.3377 A
# Frame:   973, Time: 9730.000 ps
# Rgyr: 33.4201 A
# Frame:   974, Time: 9740.000 ps
# Rgyr: 33.4813 A
# Frame:   975, Time: 9750.000 ps
# Rgyr: 33.3379 A
# Frame:   976, Time: 9760.000 ps
# Rgyr: 32.9755 A
# Frame:   977, Time: 9770.000 ps
# Rgyr: 33.1331 A
# Frame:   978, Time: 9780.000 ps
# Rgyr: 33.0445 A
# Frame:   979, Time: 9790.000 ps
# Rgyr: 33.2732 A
# Frame:   980, Time: 9800.000 ps
# Rgyr: 33.1678 A
# Frame:   981, Time: 9810.000 ps
# Rgyr: 33.4671 A
# Frame:   982, Time: 9820.000 ps
# Rgyr: 33.679 A
# Frame:   983, Time: 9830.000 ps
# Rgyr: 34.0372 A
# Frame:   984, Time: 9840.000 ps
# Rgyr: 34.0531 A
# Frame:   985, Time: 9850.000 ps
# Rgyr: 33.8924 A
# Frame:   986, Time: 9860.000 ps
# Rgyr: 34.0593 A
# Frame:   987, Time: 9870.000 ps
# Rgyr: 33.9427 A
# Frame:   988, Time: 9880.000 ps
# Rgyr: 34.0167 A
# Frame:   989, Time: 9890.000 ps
# Rgyr: 33.8562 A
# Frame:   990, Time: 9900.000 ps
# Rgyr: 34.174 A
# Frame:   991, Time: 9910.000 ps
# Rgyr: 34.1744 A
# Frame:   992, Time: 9920.000 ps
# Rgyr: 33.9794 A
# Frame:   993, Time: 9930.000 ps
# Rgyr: 34.0621 A
# Frame:   994, Time: 9940.000 ps
# Rgyr: 34.1574 A
# Frame:   995, Time: 9950.000 ps
# Rgyr: 34.1278 A
# Frame:   996, Time: 9960.000 ps
# Rgyr: 33.8948 A
# Frame:   997, Time: 9970.000 ps
# Rgyr: 33.7773 A
# Frame:   998, Time: 9980.000 ps
# Rgyr: 34.0127 A
# Frame:   999, Time: 9990.000 ps
# Rgyr: 34.0126 A
# Frame:  1000, Time: 10000.000 ps
# Rgyr: 34.1874 A
# Frame:  1001, Time: 10010.000 ps
# Rgyr: 34.4706 A
# Frame:  1002, Time: 10020.000 ps
# Rgyr: 34.4936 A
# Frame:  1003, Time: 10030.000 ps
# Rgyr: 34.6458 A
# Frame:  1004, Time: 10040.000 ps
# Rgyr: 34.3568 A
# Frame:  1005, Time: 10050.000 ps
# Rgyr: 34.6081 A
# Frame:  1006, Time: 10060.000 ps
# Rgyr: 34.2909 A
# Frame:  1007, Time: 10070.000 ps
# Rgyr: 34.1621 A
# Frame:  1008, Time: 10080.000 ps
# Rgyr: 34.1345 A
# Frame:  1009, Time: 10090.000 ps
# Rgyr: 34.2756 A
# Frame:  1010, Time: 10100.000 ps
# Rgyr: 34.1721 A
# Frame:  1011, Time: 10110.000 ps
# Rgyr: 34.0661 A
# Frame:  1012, Time: 10120.000 ps
# Rgyr: 34.0175 A
# Frame:  1013, Time: 10130.000 ps
# Rgyr: 33.9257 A
# Frame:  1014, Time: 10140.000 ps
# Rgyr: 33.9485 A
# Frame:  1015, Time: 10150.000 ps
# Rgyr: 34.2911 A
# Frame:  1016, Time: 10160.000 ps
# Rgyr: 34.3896 A
# Frame:  1017, Time: 10170.000 ps
# Rgyr: 34.3479 A
# Frame:  1018, Time: 10180.000 ps
# Rgyr: 34.1468 A
# Frame:  1019, Time: 10190.000 ps
# Rgyr: 34.2066 A
# Frame:  1020, Time: 10200.000 ps
# Rgyr: 34.4263 A
# Frame:  1021, Time: 10210.000 ps
# Rgyr: 34.0958 A
# Frame:  1022, Time: 10220.000 ps
# Rgyr: 34.253 A
# Frame:  1023, Time: 10230.000 ps
# Rgyr: 34.2786 A
# Frame:  1024, Time: 10240.000 ps
# Rgyr: 34.2055 A
# Frame:  1025, Time: 10250.000 ps
# Rgyr: 34.1691 A
# Frame:  1026, Time: 10260.000 ps
# Rgyr: 34.1861 A
# Frame:  1027, Time: 10270.000 ps
# Rgyr: 34.2206 A
# Frame:  1028, Time: 10280.000 ps
# Rgyr: 34.1659 A
# Frame:  1029, Time: 10290.000 ps
# Rgyr: 34.0205 A
# Frame:  1030, Time: 10300.000 ps
# Rgyr: 34.2152 A
# Frame:  1031, Time: 10310.000 ps
# Rgyr: 33.9392 A
# Frame:  1032, Time: 10320.000 ps
# Rgyr: 34.0161 A
# Frame:  1033, Time: 10330.000 ps
# Rgyr: 34.0576 A
# Frame:  1034, Time: 10340.000 ps
# Rgyr: 34.1307 A
# Frame:  1035, Time: 10350.000 ps
# Rgyr: 34.3712 A
# Frame:  1036, Time: 10360.000 ps
# Rgyr: 34.105 A
# Frame:  1037, Time: 10370.000 ps
# Rgyr: 34.014 A
# Frame:  1038, Time: 10380.000 ps
# Rgyr: 34.2122 A
# Frame:  1039, Time: 10390.000 ps
# Rgyr: 34.0375 A
# Frame:  1040, Time: 10400.000 ps
# Rgyr: 33.8309 A
# Frame:  1041, Time: 10410.000 ps
# Rgyr: 33.9028 A
# Frame:  1042, Time: 10420.000 ps
# Rgyr: 33.5472 A
# Frame:  1043, Time: 10430.000 ps
# Rgyr: 33.5448 A
# Frame:  1044, Time: 10440.000 ps
# Rgyr: 33.8442 A
# Frame:  1045, Time: 10450.000 ps
# Rgyr: 33.8328 A
# Frame:  1046, Time: 10460.000 ps
# Rgyr: 33.3941 A
# Frame:  1047, Time: 10470.000 ps
# Rgyr: 33.8383 A
# Frame:  1048, Time: 10480.000 ps
# Rgyr: 33.8172 A
# Frame:  1049, Time: 10490.000 ps
# Rgyr: 33.8303 A
# Frame:  1050, Time: 10500.000 ps
# Rgyr: 33.449 A
# Frame:  1051, Time: 10510.000 ps
# Rgyr: 33.1632 A
# Frame:  1052, Time: 10520.000 ps
# Rgyr: 33.3634 A
# Frame:  1053, Time: 10530.000 ps
# Rgyr: 33.2706 A
# Frame:  1054, Time: 10540.000 ps
# Rgyr: 33.1168 A
# Frame:  1055, Time: 10550.000 ps
# Rgyr: 32.7072 A
# Frame:  1056, Time: 10560.000 ps
# Rgyr: 32.5482 A
# Frame:  1057, Time: 10570.000 ps
# Rgyr: 32.7057 A
# Frame:  1058, Time: 10580.000 ps
# Rgyr: 33.1182 A
# Frame:  1059, Time: 10590.000 ps
# Rgyr: 33.0674 A
# Frame:  1060, Time: 10600.000 ps
# Rgyr: 33.1277 A
# Frame:  1061, Time: 10610.000 ps
# Rgyr: 33.1183 A
# Frame:  1062, Time: 10620.000 ps
# Rgyr: 33.0775 A
# Frame:  1063, Time: 10630.000 ps
# Rgyr: 32.8915 A
# Frame:  1064, Time: 10640.000 ps
# Rgyr: 33.1909 A
# Frame:  1065, Time: 10650.000 ps
# Rgyr: 33.3304 A
# Frame:  1066, Time: 10660.000 ps
# Rgyr: 33.275 A
# Frame:  1067, Time: 10670.000 ps
# Rgyr: 33.2377 A
# Frame:  1068, Time: 10680.000 ps
# Rgyr: 33.3024 A
# Frame:  1069, Time: 10690.000 ps
# Rgyr: 33.0452 A
# Frame:  1070, Time: 10700.000 ps
# Rgyr: 33.0559 A
# Frame:  1071, Time: 10710.000 ps
# Rgyr: 33.3985 A
# Frame:  1072, Time: 10720.000 ps
# Rgyr: 33.1914 A
# Frame:  1073, Time: 10730.000 ps
# Rgyr: 32.7132 A
# Frame:  1074, Time: 10740.000 ps
# Rgyr: 32.8576 A
# Frame:  1075, Time: 10750.000 ps
# Rgyr: 33.2597 A
# Frame:  1076, Time: 10760.000 ps
# Rgyr: 33.3358 A
# Frame:  1077, Time: 10770.000 ps
# Rgyr: 33.0136 A
# Frame:  1078, Time: 10780.000 ps
# Rgyr: 32.8134 A
# Frame:  1079, Time: 10790.000 ps
# Rgyr: 32.8541 A
# Frame:  1080, Time: 10800.000 ps
# Rgyr: 33.083 A
# Frame:  1081, Time: 10810.000 ps
# Rgyr: 32.858 A
# Frame:  1082, Time: 10820.000 ps
# Rgyr: 32.936 A
# Frame:  1083, Time: 10830.000 ps
# Rgyr: 32.8736 A
# Frame:  1084, Time: 10840.000 ps
# Rgyr: 32.8241 A
# Frame:  1085, Time: 10850.000 ps
# Rgyr: 32.9088 A
# Frame:  1086, Time: 10860.000 ps
# Rgyr: 32.8156 A
# Frame:  1087, Time: 10870.000 ps
# Rgyr: 32.6941 A
# Frame:  1088, Time: 10880.000 ps
# Rgyr: 32.5104 A
# Frame:  1089, Time: 10890.000 ps
# Rgyr: 32.5772 A
# Frame:  1090, Time: 10900.000 ps
# Rgyr: 32.6537 A
# Frame:  1091, Time: 10910.000 ps
# Rgyr: 32.6341 A
# Frame:  1092, Time: 10920.000 ps
# Rgyr: 32.6027 A
# Frame:  1093, Time: 10930.000 ps
# Rgyr: 32.7367 A
# Frame:  1094, Time: 10940.000 ps
# Rgyr: 32.4942 A
# Frame:  1095, Time: 10950.000 ps
# Rgyr: 32.4787 A
# Frame:  1096, Time: 10960.000 ps
# Rgyr: 32.3476 A
# Frame:  1097, Time: 10970.000 ps
# Rgyr: 32.4167 A
# Frame:  1098, Time: 10980.000 ps
# Rgyr: 32.3816 A
# Frame:  1099, Time: 10990.000 ps
# Rgyr: 32.3689 A
# Frame:  1100, Time: 11000.000 ps
# Rgyr: 32.5839 A
# Frame:  1101, Time: 11010.000 ps
# Rgyr: 32.5785 A
# Frame:  1102, Time: 11020.000 ps
# Rgyr: 32.4779 A
# Frame:  1103, Time: 11030.000 ps
# Rgyr: 32.5735 A
# Frame:  1104, Time: 11040.000 ps
# Rgyr: 32.5003 A
# Frame:  1105, Time: 11050.000 ps
# Rgyr: 32.511 A
# Frame:  1106, Time: 11060.000 ps
# Rgyr: 32.3538 A
# Frame:  1107, Time: 11070.000 ps
# Rgyr: 32.6016 A
# Frame:  1108, Time: 11080.000 ps
# Rgyr: 32.5706 A
# Frame:  1109, Time: 11090.000 ps
# Rgyr: 32.6071 A
# Frame:  1110, Time: 11100.000 ps
# Rgyr: 32.3131 A
# Frame:  1111, Time: 11110.000 ps
# Rgyr: 32.5272 A
# Frame:  1112, Time: 11120.000 ps
# Rgyr: 32.4303 A
# Frame:  1113, Time: 11130.000 ps
# Rgyr: 32.2448 A
# Frame:  1114, Time: 11140.000 ps
# Rgyr: 32.2882 A
# Frame:  1115, Time: 11150.000 ps
# Rgyr: 32.1843 A
# Frame:  1116, Time: 11160.000 ps
# Rgyr: 32.4079 A
# Frame:  1117, Time: 11170.000 ps
# Rgyr: 32.4619 A
# Frame:  1118, Time: 11180.000 ps
# Rgyr: 32.7503 A
# Frame:  1119, Time: 11190.000 ps
# Rgyr: 32.6631 A
# Frame:  1120, Time: 11200.000 ps
# Rgyr: 32.9225 A
# Frame:  1121, Time: 11210.000 ps
# Rgyr: 32.8238 A
# Frame:  1122, Time: 11220.000 ps
# Rgyr: 33.0791 A
# Frame:  1123, Time: 11230.000 ps
# Rgyr: 33.1646 A
# Frame:  1124, Time: 11240.000 ps
# Rgyr: 33.2208 A
# Frame:  1125, Time: 11250.000 ps
# Rgyr: 32.8795 A
# Frame:  1126, Time: 11260.000 ps
# Rgyr: 32.8271 A
# Frame:  1127, Time: 11270.000 ps
# Rgyr: 32.7497 A
# Frame:  1128, Time: 11280.000 ps
# Rgyr: 32.7804 A
# Frame:  1129, Time: 11290.000 ps
# Rgyr: 33.0321 A
# Frame:  1130, Time: 11300.000 ps
# Rgyr: 33.1129 A
# Frame:  1131, Time: 11310.000 ps
# Rgyr: 33.1048 A
# Frame:  1132, Time: 11320.000 ps
# Rgyr: 33.0461 A
# Frame:  1133, Time: 11330.000 ps
# Rgyr: 33.3857 A
# Frame:  1134, Time: 11340.000 ps
# Rgyr: 33.2642 A
# Frame:  1135, Time: 11350.000 ps
# Rgyr: 33.6903 A
# Frame:  1136, Time: 11360.000 ps
# Rgyr: 33.2986 A
# Frame:  1137, Time: 11370.000 ps
# Rgyr: 33.1543 A
# Frame:  1138, Time: 11380.000 ps
# Rgyr: 33.0416 A
# Frame:  1139, Time: 11390.000 ps
# Rgyr: 33.1629 A
# ...
# Frame:  4674, Time: 46740.000 ps
# Rgyr: 28.7321 A
# Frame:  4675, Time: 46750.000 ps
# Rgyr: 28.7275 A
# Frame:  4676, Time: 46760.000 ps
# Rgyr: 28.5862 A
# Frame:  4677, Time: 46770.000 ps
# Rgyr: 28.608 A
# Frame:  4678, Time: 46780.000 ps
# Rgyr: 28.6109 A
# Frame:  4679, Time: 46790.000 ps
# Rgyr: 28.616 A
# Frame:  4680, Time: 46800.000 ps
# Rgyr: 28.485 A
# Frame:  4681, Time: 46810.000 ps
# Rgyr: 28.7472 A
# Frame:  4682, Time: 46820.000 ps
# Rgyr: 28.8035 A
# Frame:  4683, Time: 46830.000 ps
# Rgyr: 28.7695 A
# Frame:  4684, Time: 46840.000 ps
# Rgyr: 28.5584 A
# Frame:  4685, Time: 46850.000 ps
# Rgyr: 28.3425 A
# Frame:  4686, Time: 46860.000 ps
# Rgyr: 28.6066 A
# Frame:  4687, Time: 46870.000 ps
# Rgyr: 28.4002 A
# Frame:  4688, Time: 46880.000 ps
# Rgyr: 28.5858 A
# Frame:  4689, Time: 46890.000 ps
# Rgyr: 28.5152 A
# Frame:  4690, Time: 46900.000 ps
# Rgyr: 28.4793 A
# Frame:  4691, Time: 46910.000 ps
# Rgyr: 28.7366 A
# Frame:  4692, Time: 46920.000 ps
# Rgyr: 28.6523 A
# Frame:  4693, Time: 46930.000 ps
# Rgyr: 28.6973 A
# Frame:  4694, Time: 46940.000 ps
# Rgyr: 28.7693 A
# Frame:  4695, Time: 46950.000 ps
# Rgyr: 29.0746 A
# Frame:  4696, Time: 46960.000 ps
# Rgyr: 29.0869 A
# Frame:  4697, Time: 46970.000 ps
# Rgyr: 28.8225 A
# Frame:  4698, Time: 46980.000 ps
# Rgyr: 28.6979 A
# Frame:  4699, Time: 46990.000 ps
# Rgyr: 28.7067 A
# Frame:  4700, Time: 47000.000 ps
# Rgyr: 28.6253 A
# Frame:  4701, Time: 47010.000 ps
# Rgyr: 28.5038 A
# Frame:  4702, Time: 47020.000 ps
# Rgyr: 28.3402 A
# Frame:  4703, Time: 47030.000 ps
# Rgyr: 28.2233 A
# Frame:  4704, Time: 47040.000 ps
# Rgyr: 28.3606 A
# Frame:  4705, Time: 47050.000 ps
# Rgyr: 28.6597 A
# Frame:  4706, Time: 47060.000 ps
# Rgyr: 28.8268 A
# Frame:  4707, Time: 47070.000 ps
# Rgyr: 28.5611 A
# Frame:  4708, Time: 47080.000 ps
# Rgyr: 28.6018 A
# Frame:  4709, Time: 47090.000 ps
# Rgyr: 28.5595 A
# Frame:  4710, Time: 47100.000 ps
# Rgyr: 28.5689 A
# Frame:  4711, Time: 47110.000 ps
# Rgyr: 28.7412 A
# Frame:  4712, Time: 47120.000 ps
# Rgyr: 28.3906 A
# Frame:  4713, Time: 47130.000 ps
# Rgyr: 28.4638 A
# Frame:  4714, Time: 47140.000 ps
# Rgyr: 28.5271 A
# Frame:  4715, Time: 47150.000 ps
# Rgyr: 28.3589 A
# Frame:  4716, Time: 47160.000 ps
# Rgyr: 28.3002 A
# Frame:  4717, Time: 47170.000 ps
# Rgyr: 28.1088 A
# Frame:  4718, Time: 47180.000 ps
# Rgyr: 28.2956 A
# Frame:  4719, Time: 47190.000 ps
# Rgyr: 28.3149 A
# Frame:  4720, Time: 47200.000 ps
# Rgyr: 28.4088 A
# Frame:  4721, Time: 47210.000 ps
# Rgyr: 28.3532 A
# Frame:  4722, Time: 47220.000 ps
# Rgyr: 28.4869 A
# Frame:  4723, Time: 47230.000 ps
# Rgyr: 28.3923 A
# Frame:  4724, Time: 47240.000 ps
# Rgyr: 28.6508 A
# Frame:  4725, Time: 47250.000 ps
# Rgyr: 28.2958 A
# Frame:  4726, Time: 47260.000 ps
# Rgyr: 28.4526 A
# Frame:  4727, Time: 47270.000 ps
# Rgyr: 28.6045 A
# Frame:  4728, Time: 47280.000 ps
# Rgyr: 28.4455 A
# Frame:  4729, Time: 47290.000 ps
# Rgyr: 28.7278 A
# Frame:  4730, Time: 47300.000 ps
# Rgyr: 28.838 A
# Frame:  4731, Time: 47310.000 ps
# Rgyr: 28.4371 A
# Frame:  4732, Time: 47320.000 ps
# Rgyr: 28.6006 A
# Frame:  4733, Time: 47330.000 ps
# Rgyr: 28.8133 A
# Frame:  4734, Time: 47340.000 ps
# Rgyr: 28.7137 A
# Frame:  4735, Time: 47350.000 ps
# Rgyr: 28.8115 A
# Frame:  4736, Time: 47360.000 ps
# Rgyr: 28.737 A
# Frame:  4737, Time: 47370.000 ps
# Rgyr: 28.772 A
# Frame:  4738, Time: 47380.000 ps
# Rgyr: 28.9902 A
# Frame:  4739, Time: 47390.000 ps
# Rgyr: 29.3645 A
# Frame:  4740, Time: 47400.000 ps
# Rgyr: 29.1413 A
# Frame:  4741, Time: 47410.000 ps
# Rgyr: 29.1535 A
# Frame:  4742, Time: 47420.000 ps
# Rgyr: 28.8877 A
# Frame:  4743, Time: 47430.000 ps
# Rgyr: 28.9057 A
# Frame:  4744, Time: 47440.000 ps
# Rgyr: 28.9357 A
# Frame:  4745, Time: 47450.000 ps
# Rgyr: 28.7807 A
# Frame:  4746, Time: 47460.000 ps
# Rgyr: 28.8521 A
# Frame:  4747, Time: 47470.000 ps
# Rgyr: 28.974 A
# Frame:  4748, Time: 47480.000 ps
# Rgyr: 28.6635 A
# Frame:  4749, Time: 47490.000 ps
# Rgyr: 28.6805 A
# Frame:  4750, Time: 47500.000 ps
# Rgyr: 28.5963 A
# Frame:  4751, Time: 47510.000 ps
# Rgyr: 28.601 A
# Frame:  4752, Time: 47520.000 ps
# Rgyr: 28.5112 A
# Frame:  4753, Time: 47530.000 ps
# Rgyr: 28.4782 A
# Frame:  4754, Time: 47540.000 ps
# Rgyr: 28.4747 A
# Frame:  4755, Time: 47550.000 ps
# Rgyr: 28.3227 A
# Frame:  4756, Time: 47560.000 ps
# Rgyr: 28.0884 A
# Frame:  4757, Time: 47570.000 ps
# Rgyr: 28.1699 A
# Frame:  4758, Time: 47580.000 ps
# Rgyr: 28.4012 A
# Frame:  4759, Time: 47590.000 ps
# Rgyr: 28.4632 A
# Frame:  4760, Time: 47600.000 ps
# Rgyr: 28.4728 A
# Frame:  4761, Time: 47610.000 ps
# Rgyr: 28.4418 A
# Frame:  4762, Time: 47620.000 ps
# Rgyr: 28.8588 A
# Frame:  4763, Time: 47630.000 ps
# Rgyr: 28.8756 A
# Frame:  4764, Time: 47640.000 ps
# Rgyr: 28.5083 A
# Frame:  4765, Time: 47650.000 ps
# Rgyr: 28.3835 A
# Frame:  4766, Time: 47660.000 ps
# Rgyr: 28.2878 A
# Frame:  4767, Time: 47670.000 ps
# Rgyr: 28.5202 A
# Frame:  4768, Time: 47680.000 ps
# Rgyr: 28.6154 A
# Frame:  4769, Time: 47690.000 ps
# Rgyr: 28.4189 A
# Frame:  4770, Time: 47700.000 ps
# Rgyr: 28.4432 A
# Frame:  4771, Time: 47710.000 ps
# Rgyr: 28.4705 A
# Frame:  4772, Time: 47720.000 ps
# Rgyr: 28.7157 A
# Frame:  4773, Time: 47730.000 ps
# Rgyr: 28.5027 A
# Frame:  4774, Time: 47740.000 ps
# Rgyr: 28.643 A
# Frame:  4775, Time: 47750.000 ps
# Rgyr: 28.6653 A
# Frame:  4776, Time: 47760.000 ps
# Rgyr: 28.6617 A
# Frame:  4777, Time: 47770.000 ps
# Rgyr: 28.5191 A
# Frame:  4778, Time: 47780.000 ps
# Rgyr: 28.456 A
# Frame:  4779, Time: 47790.000 ps
# Rgyr: 28.6932 A
# Frame:  4780, Time: 47800.000 ps
# Rgyr: 28.4426 A
# Frame:  4781, Time: 47810.000 ps
# Rgyr: 28.4064 A
# Frame:  4782, Time: 47820.000 ps
# Rgyr: 28.5054 A
# Frame:  4783, Time: 47830.000 ps
# Rgyr: 28.4722 A
# Frame:  4784, Time: 47840.000 ps
# Rgyr: 28.5437 A
# Frame:  4785, Time: 47850.000 ps
# Rgyr: 28.6326 A
# Frame:  4786, Time: 47860.000 ps
# Rgyr: 28.5151 A
# Frame:  4787, Time: 47870.000 ps
# Rgyr: 28.4851 A
# Frame:  4788, Time: 47880.000 ps
# Rgyr: 28.707 A
# Frame:  4789, Time: 47890.000 ps
# Rgyr: 28.4166 A
# Frame:  4790, Time: 47900.000 ps
# Rgyr: 28.4717 A
# Frame:  4791, Time: 47910.000 ps
# Rgyr: 28.6399 A
# Frame:  4792, Time: 47920.000 ps
# Rgyr: 28.7292 A
# Frame:  4793, Time: 47930.000 ps
# Rgyr: 28.6976 A
# Frame:  4794, Time: 47940.000 ps
# Rgyr: 28.5207 A
# Frame:  4795, Time: 47950.000 ps
# Rgyr: 28.5277 A
# Frame:  4796, Time: 47960.000 ps
# Rgyr: 28.7546 A
# Frame:  4797, Time: 47970.000 ps
# Rgyr: 28.6328 A
# Frame:  4798, Time: 47980.000 ps
# Rgyr: 28.558 A
# Frame:  4799, Time: 47990.000 ps
# Rgyr: 28.6124 A
# Frame:  4800, Time: 48000.000 ps
# Rgyr: 28.5673 A
# Frame:  4801, Time: 48010.000 ps
# Rgyr: 28.6668 A
# Frame:  4802, Time: 48020.000 ps
# Rgyr: 28.2978 A
# Frame:  4803, Time: 48030.000 ps
# Rgyr: 28.4141 A
# Frame:  4804, Time: 48040.000 ps
# Rgyr: 28.6251 A
# Frame:  4805, Time: 48050.000 ps
# Rgyr: 28.5092 A
# Frame:  4806, Time: 48060.000 ps
# Rgyr: 28.6116 A
# Frame:  4807, Time: 48070.000 ps
# Rgyr: 28.5583 A
# Frame:  4808, Time: 48080.000 ps
# Rgyr: 28.6483 A
# Frame:  4809, Time: 48090.000 ps
# Rgyr: 28.7609 A
# Frame:  4810, Time: 48100.000 ps
# Rgyr: 28.6425 A
# Frame:  4811, Time: 48110.000 ps
# Rgyr: 29.0513 A
# Frame:  4812, Time: 48120.000 ps
# Rgyr: 29.1714 A
# Frame:  4813, Time: 48130.000 ps
# Rgyr: 28.9636 A
# Frame:  4814, Time: 48140.000 ps
# Rgyr: 28.7929 A
# Frame:  4815, Time: 48150.000 ps
# Rgyr: 29.1272 A
# Frame:  4816, Time: 48160.000 ps
# Rgyr: 29.0854 A
# Frame:  4817, Time: 48170.000 ps
# Rgyr: 29.0712 A
# Frame:  4818, Time: 48180.000 ps
# Rgyr: 29.0829 A
# Frame:  4819, Time: 48190.000 ps
# Rgyr: 29.4252 A
# Frame:  4820, Time: 48200.000 ps
# Rgyr: 29.0201 A
# Frame:  4821, Time: 48210.000 ps
# Rgyr: 29.0658 A
# Frame:  4822, Time: 48220.000 ps
# Rgyr: 29.2995 A
# Frame:  4823, Time: 48230.000 ps
# Rgyr: 29.3246 A
# Frame:  4824, Time: 48240.000 ps
# Rgyr: 29.2214 A
# Frame:  4825, Time: 48250.000 ps
# Rgyr: 29.2961 A
# Frame:  4826, Time: 48260.000 ps
# Rgyr: 29.3486 A
# Frame:  4827, Time: 48270.000 ps
# Rgyr: 29.2781 A
# Frame:  4828, Time: 48280.000 ps
# Rgyr: 29.2105 A
# Frame:  4829, Time: 48290.000 ps
# Rgyr: 29.4855 A
# Frame:  4830, Time: 48300.000 ps
# Rgyr: 29.7446 A
# Frame:  4831, Time: 48310.000 ps
# Rgyr: 29.4225 A
# Frame:  4832, Time: 48320.000 ps
# Rgyr: 29.3045 A
# Frame:  4833, Time: 48330.000 ps
# Rgyr: 29.4345 A
# Frame:  4834, Time: 48340.000 ps
# Rgyr: 29.2663 A
# Frame:  4835, Time: 48350.000 ps
# Rgyr: 29.3323 A
# Frame:  4836, Time: 48360.000 ps
# Rgyr: 29.1237 A
# Frame:  4837, Time: 48370.000 ps
# Rgyr: 29.102 A
# Frame:  4838, Time: 48380.000 ps
# Rgyr: 29.1658 A
# Frame:  4839, Time: 48390.000 ps
# Rgyr: 29.395 A
# Frame:  4840, Time: 48400.000 ps
# Rgyr: 29.1844 A
# Frame:  4841, Time: 48410.000 ps
# Rgyr: 29.157 A
# Frame:  4842, Time: 48420.000 ps
# Rgyr: 29.3359 A
# Frame:  4843, Time: 48430.000 ps
# Rgyr: 28.8524 A
# Frame:  4844, Time: 48440.000 ps
# Rgyr: 29.1521 A
# Frame:  4845, Time: 48450.000 ps
# Rgyr: 28.7771 A
# Frame:  4846, Time: 48460.000 ps
# Rgyr: 28.7384 A
# Frame:  4847, Time: 48470.000 ps
# Rgyr: 28.766 A
# Frame:  4848, Time: 48480.000 ps
# Rgyr: 28.8744 A
# Frame:  4849, Time: 48490.000 ps
# Rgyr: 28.6034 A
# Frame:  4850, Time: 48500.000 ps
# Rgyr: 28.8778 A
# Frame:  4851, Time: 48510.000 ps
# Rgyr: 28.9944 A
# Frame:  4852, Time: 48520.000 ps
# Rgyr: 28.5881 A
# Frame:  4853, Time: 48530.000 ps
# Rgyr: 28.9186 A
# Frame:  4854, Time: 48540.000 ps
# Rgyr: 28.8694 A
# Frame:  4855, Time: 48550.000 ps
# Rgyr: 28.8163 A
# Frame:  4856, Time: 48560.000 ps
# Rgyr: 28.7345 A
# Frame:  4857, Time: 48570.000 ps
# Rgyr: 28.7115 A
# Frame:  4858, Time: 48580.000 ps
# Rgyr: 28.7885 A
# Frame:  4859, Time: 48590.000 ps
# Rgyr: 28.7958 A
# Frame:  4860, Time: 48600.000 ps
# Rgyr: 28.801 A
# Frame:  4861, Time: 48610.000 ps
# Rgyr: 28.9613 A
# Frame:  4862, Time: 48620.000 ps
# Rgyr: 29.2402 A
# Frame:  4863, Time: 48630.000 ps
# Rgyr: 29.4896 A
# Frame:  4864, Time: 48640.000 ps
# Rgyr: 29.1934 A
# Frame:  4865, Time: 48650.000 ps
# Rgyr: 29.1676 A
# Frame:  4866, Time: 48660.000 ps
# Rgyr: 28.9957 A
# Frame:  4867, Time: 48670.000 ps
# Rgyr: 29.1485 A
# Frame:  4868, Time: 48680.000 ps
# Rgyr: 29.1337 A
# Frame:  4869, Time: 48690.000 ps
# Rgyr: 29.1122 A
# Frame:  4870, Time: 48700.000 ps
# Rgyr: 28.8876 A
# Frame:  4871, Time: 48710.000 ps
# Rgyr: 29.0871 A
# Frame:  4872, Time: 48720.000 ps
# Rgyr: 29.2159 A
# Frame:  4873, Time: 48730.000 ps
# Rgyr: 28.6742 A
# Frame:  4874, Time: 48740.000 ps
# Rgyr: 28.9121 A
# Frame:  4875, Time: 48750.000 ps
# Rgyr: 28.6334 A
# Frame:  4876, Time: 48760.000 ps
# Rgyr: 28.892 A
# Frame:  4877, Time: 48770.000 ps
# Rgyr: 28.948 A
# Frame:  4878, Time: 48780.000 ps
# Rgyr: 29.0295 A
# Frame:  4879, Time: 48790.000 ps
# Rgyr: 28.8555 A
# Frame:  4880, Time: 48800.000 ps
# Rgyr: 28.9003 A
# Frame:  4881, Time: 48810.000 ps
# Rgyr: 28.8125 A
# Frame:  4882, Time: 48820.000 ps
# Rgyr: 28.7192 A
# Frame:  4883, Time: 48830.000 ps
# Rgyr: 28.9233 A
# Frame:  4884, Time: 48840.000 ps
# Rgyr: 28.7435 A
# Frame:  4885, Time: 48850.000 ps
# Rgyr: 28.6208 A
# Frame:  4886, Time: 48860.000 ps
# Rgyr: 28.7435 A
# Frame:  4887, Time: 48870.000 ps
# Rgyr: 28.3203 A
# Frame:  4888, Time: 48880.000 ps
# Rgyr: 28.6375 A
# Frame:  4889, Time: 48890.000 ps
# Rgyr: 28.8454 A
# Frame:  4890, Time: 48900.000 ps
# Rgyr: 28.5817 A
# Frame:  4891, Time: 48910.000 ps
# Rgyr: 28.6229 A
# Frame:  4892, Time: 48920.000 ps
# Rgyr: 28.6082 A
# Frame:  4893, Time: 48930.000 ps
# Rgyr: 28.436 A
# Frame:  4894, Time: 48940.000 ps
# Rgyr: 28.369 A
# Frame:  4895, Time: 48950.000 ps
# Rgyr: 28.3369 A
# Frame:  4896, Time: 48960.000 ps
# Rgyr: 28.3892 A
# Frame:  4897, Time: 48970.000 ps
# Rgyr: 28.5763 A
# Frame:  4898, Time: 48980.000 ps
# Rgyr: 28.7543 A
# Frame:  4899, Time: 48990.000 ps
# Rgyr: 28.6314 A
# Frame:  4900, Time: 49000.000 ps
# Rgyr: 28.5049 A
# Frame:  4901, Time: 49010.000 ps
# Rgyr: 28.5708 A
# Frame:  4902, Time: 49020.000 ps
# Rgyr: 28.7883 A
# Frame:  4903, Time: 49030.000 ps
# Rgyr: 28.7849 A
# Frame:  4904, Time: 49040.000 ps
# Rgyr: 28.8036 A
# Frame:  4905, Time: 49050.000 ps
# Rgyr: 28.6969 A
# Frame:  4906, Time: 49060.000 ps
# Rgyr: 28.6796 A
# Frame:  4907, Time: 49070.000 ps
# Rgyr: 28.6299 A
# Frame:  4908, Time: 49080.000 ps
# Rgyr: 28.6421 A
# Frame:  4909, Time: 49090.000 ps
# Rgyr: 28.563 A
# Frame:  4910, Time: 49100.000 ps
# Rgyr: 28.561 A
# Frame:  4911, Time: 49110.000 ps
# Rgyr: 28.066 A
# Frame:  4912, Time: 49120.000 ps
# Rgyr: 28.3505 A
# Frame:  4913, Time: 49130.000 ps
# Rgyr: 28.4929 A
# Frame:  4914, Time: 49140.000 ps
# Rgyr: 28.4104 A
# Frame:  4915, Time: 49150.000 ps
# Rgyr: 28.4461 A
# Frame:  4916, Time: 49160.000 ps
# Rgyr: 28.3051 A
# Frame:  4917, Time: 49170.000 ps
# Rgyr: 28.6234 A
# Frame:  4918, Time: 49180.000 ps
# Rgyr: 28.3804 A
# Frame:  4919, Time: 49190.000 ps
# Rgyr: 28.4792 A
# Frame:  4920, Time: 49200.000 ps
# Rgyr: 28.4142 A
# Frame:  4921, Time: 49210.000 ps
# Rgyr: 28.4526 A
# Frame:  4922, Time: 49220.000 ps
# Rgyr: 28.6175 A
# Frame:  4923, Time: 49230.000 ps
# Rgyr: 28.6469 A
# Frame:  4924, Time: 49240.000 ps
# Rgyr: 28.6873 A
# Frame:  4925, Time: 49250.000 ps
# Rgyr: 28.9731 A
# Frame:  4926, Time: 49260.000 ps
# Rgyr: 28.8987 A
# Frame:  4927, Time: 49270.000 ps
# Rgyr: 28.9638 A
# Frame:  4928, Time: 49280.000 ps
# Rgyr: 28.8698 A
# Frame:  4929, Time: 49290.000 ps
# Rgyr: 28.8037 A
# Frame:  4930, Time: 49300.000 ps
# Rgyr: 29.0708 A
# Frame:  4931, Time: 49310.000 ps
# Rgyr: 28.8311 A
# Frame:  4932, Time: 49320.000 ps
# Rgyr: 28.6727 A
# Frame:  4933, Time: 49330.000 ps
# Rgyr: 28.4043 A
# Frame:  4934, Time: 49340.000 ps
# Rgyr: 28.697 A
# Frame:  4935, Time: 49350.000 ps
# Rgyr: 28.6012 A
# Frame:  4936, Time: 49360.000 ps
# Rgyr: 28.717 A
# Frame:  4937, Time: 49370.000 ps
# Rgyr: 28.4516 A
# Frame:  4938, Time: 49380.000 ps
# Rgyr: 28.3228 A
# Frame:  4939, Time: 49390.000 ps
# Rgyr: 28.4147 A
# Frame:  4940, Time: 49400.000 ps
# Rgyr: 28.2125 A
# Frame:  4941, Time: 49410.000 ps
# Rgyr: 28.1341 A
# Frame:  4942, Time: 49420.000 ps
# Rgyr: 28.2048 A
# Frame:  4943, Time: 49430.000 ps
# Rgyr: 28.2282 A
# Frame:  4944, Time: 49440.000 ps
# Rgyr: 28.0155 A
# Frame:  4945, Time: 49450.000 ps
# Rgyr: 27.8681 A
# Frame:  4946, Time: 49460.000 ps
# Rgyr: 27.8518 A
# Frame:  4947, Time: 49470.000 ps
# Rgyr: 27.7982 A
# Frame:  4948, Time: 49480.000 ps
# Rgyr: 27.8698 A
# Frame:  4949, Time: 49490.000 ps
# Rgyr: 27.843 A
# Frame:  4950, Time: 49500.000 ps
# Rgyr: 27.894 A
# Frame:  4951, Time: 49510.000 ps
# Rgyr: 28.1116 A
# Frame:  4952, Time: 49520.000 ps
# Rgyr: 28.4082 A
# Frame:  4953, Time: 49530.000 ps
# Rgyr: 28.2295 A
# Frame:  4954, Time: 49540.000 ps
# Rgyr: 28.7403 A
# Frame:  4955, Time: 49550.000 ps
# Rgyr: 28.3562 A
# Frame:  4956, Time: 49560.000 ps
# Rgyr: 28.2092 A
# Frame:  4957, Time: 49570.000 ps
# Rgyr: 28.424 A
# Frame:  4958, Time: 49580.000 ps
# Rgyr: 28.4021 A
# Frame:  4959, Time: 49590.000 ps
# Rgyr: 28.2957 A
# Frame:  4960, Time: 49600.000 ps
# Rgyr: 28.4157 A
# Frame:  4961, Time: 49610.000 ps
# Rgyr: 28.2916 A
# Frame:  4962, Time: 49620.000 ps
# Rgyr: 28.3268 A
# Frame:  4963, Time: 49630.000 ps
# Rgyr: 28.242 A
# Frame:  4964, Time: 49640.000 ps
# Rgyr: 28.2877 A
# Frame:  4965, Time: 49650.000 ps
# Rgyr: 28.173 A
# Frame:  4966, Time: 49660.000 ps
# Rgyr: 28.3296 A
# Frame:  4967, Time: 49670.000 ps
# Rgyr: 28.2914 A
# Frame:  4968, Time: 49680.000 ps
# Rgyr: 28.4774 A
# Frame:  4969, Time: 49690.000 ps
# Rgyr: 28.4316 A
# Frame:  4970, Time: 49700.000 ps
# Rgyr: 28.3689 A
# Frame:  4971, Time: 49710.000 ps
# Rgyr: 28.3878 A
# Frame:  4972, Time: 49720.000 ps
# Rgyr: 28.0677 A
# Frame:  4973, Time: 49730.000 ps
# Rgyr: 28.0733 A
# Frame:  4974, Time: 49740.000 ps
# Rgyr: 27.9773 A
# Frame:  4975, Time: 49750.000 ps
# Rgyr: 28.0609 A
# Frame:  4976, Time: 49760.000 ps
# Rgyr: 27.9072 A
# Frame:  4977, Time: 49770.000 ps
# Rgyr: 27.7041 A
# Frame:  4978, Time: 49780.000 ps
# Rgyr: 27.6406 A
# Frame:  4979, Time: 49790.000 ps
# Rgyr: 27.5534 A
# Frame:  4980, Time: 49800.000 ps
# Rgyr: 27.798 A
# Frame:  4981, Time: 49810.000 ps
# Rgyr: 27.8887 A
# Frame:  4982, Time: 49820.000 ps
# Rgyr: 27.5732 A
# Frame:  4983, Time: 49830.000 ps
# Rgyr: 27.8378 A
# Frame:  4984, Time: 49840.000 ps
# Rgyr: 27.6785 A
# Frame:  4985, Time: 49850.000 ps
# Rgyr: 27.7511 A
# Frame:  4986, Time: 49860.000 ps
# Rgyr: 27.8599 A
# Frame:  4987, Time: 49870.000 ps
# Rgyr: 27.9844 A
# Frame:  4988, Time: 49880.000 ps
# Rgyr: 28.1399 A
# Frame:  4989, Time: 49890.000 ps
# Rgyr: 27.9863 A
# Frame:  4990, Time: 49900.000 ps
# Rgyr: 27.9345 A
# Frame:  4991, Time: 49910.000 ps
# Rgyr: 27.9455 A
# Frame:  4992, Time: 49920.000 ps
# Rgyr: 27.7287 A
# Frame:  4993, Time: 49930.000 ps
# Rgyr: 27.7862 A
# Frame:  4994, Time: 49940.000 ps
# Rgyr: 27.6497 A
# Frame:  4995, Time: 49950.000 ps
# Rgyr: 27.581 A
# Frame:  4996, Time: 49960.000 ps
# Rgyr: 27.8425 A
# Frame:  4997, Time: 49970.000 ps
# Rgyr: 27.8662 A
# Frame:  4998, Time: 49980.000 ps
# Rgyr: 27.7019 A
# Frame:  4999, Time: 49990.000 ps
# Rgyr: 27.7963 A
# Frame:  5000, Time: 50000.000 ps
# Rgyr: 27.8606 A

# %% [markdown]
# The time attribute contains the current time step. The Reader only contains information about one time step: imagine a cursor or pointer moving along the trajectory file. Where the cursor points, there’s you current coordinates, frame number, and time.
#
# Normally you will collect the data in a list or array, e.g.

# %%
# Alpha-synuclein

Rgyr2KKW = []
#Rmsd = []
#protein = u.select_atoms("protein and not name H*")
#print(len(protein))
for ts in u.trajectory:
    #R = mda.analysis.rms.RMSD(u, u, select='protein', ref_frame=0)
    #R = rms.rmsd(u, u)-->RIGHT COMMAND (although rmsd and not RMSD)
    #Rmsd.append((u.trajectory.time, R))
    #Rmsd.append((u.trajectory.time, protein.rmsd.RMSD()))
    Rgyr2KKW.append((u.trajectory.time, protein.radius_of_gyration()))
Rgyr2KKW = np.array(Rgyr2KKW)
Rgyr2KKW[:,0] = Rgyr2KKW[:,0]/1000 
df_alpha_syn_rg = pd.DataFrame(Rgyr2KKW, columns=['Time (ns)', 'Rg'])
df_alpha_syn_rg.to_csv('alpha-syn_Rg_data.csv')

#print(alpha_syn_pairRMSD)
#Rmsd = np.array(Rmsd)

#R2KKW = rms.RMSD(u, u, select='backbone', ref_frame=0)
#R2KKW.run()
#R2KKW.results.rmsd.shape

# Lysosyme
'''
RgyrLyso = []
#Rmsd = []
protein = uw.select_atoms("protein")
for ts in uw.trajectory:
    #R = mda.analysis.rms.RMSD(u, u, select='protein', ref_frame=0)
    #R = rms.rmsd(u, u)-->RIGHT COMMAND (although rmsd and not RMSD)
    #Rmsd.append((u.trajectory.time, R))
    #Rmsd.append((u.trajectory.time, protein.rmsd.RMSD()))
    RgyrLyso.append((uw.trajectory.time, protein.radius_of_gyration()))
RgyrLyso = np.array(RgyrLyso)
#Rmsd = np.array(Rmsd)0
RLyso = rms.RMSD(uw, uw, select='backbone', ref_frame=0)
RLyso.run()
RLyso.results.rmsd.shape
'''

# %%
from MDAnalysis.analysis import diffusionmap, align, rms
#calculate pairwise-RMSD
protein = u.select_atoms("protein and not name H*")
matrix = diffusionmap.DistanceMatrix(protein, select='name CA').run()

df_alpha_syn_pairRMSD = pd.DataFrame(matrix.dist_matrix)

df_alpha_syn_pairRMSD.to_csv('alpha-syn_pairRMSD_data.csv')

# %%
# RMSF calcualtion
# Alpha-synuclein
from MDAnalysis.analysis import rms, align

#average = align.AverageStructure(u, u, select='protein and name CA',ref_frame=0).run()
#ref = average.results.universe


#aligner = align.AlignTraj(u, ref,select='protein and name CA',in_memory=True).run()
#print('aligning done')
c_alphas_alpha_syn = u.select_atoms('protein and name CA')
RMSF_alpha_syn = rms.RMSF(c_alphas_alpha_syn).run()
df_alpha_syn_rmsf = pd.DataFrame(RMSF_alpha_syn, columns=['RMSF'])
print('alpha syn done')

# %%
# Lysosyme
average_uw = align.AverageStructure(uw, uw, select='protein and name CA',
                                 ref_frame=0).run()
ref_uw = average_uw.results.universe

aligner = align.AlignTraj(uw, ref_uw,
                          select='protein and name CA',
                          in_memory=True).run()
# alignment done

c_alphas_lys = uw.select_atoms('protein and name CA')
RMSF_lys = rms.RMSF(c_alphas_lys).run()

# %%
# Adjusting to nanosectonds
# alpha-syn results rmsd
R2KKW.results.rmsd[:,1] = R2KKW.results.rmsd[:,1]/1000
'''
# Lysosyme results rmsd
RLyso.results.rmsd[:,1] = RLyso.results.rmsd[:,1]/1000
'''

# %%
# RMSD plot
df_alpha_syn = pd.DataFrame(R2KKW.results.rmsd, columns=['Frame', 'Time (ns)', 'RMSD'])
#dw_lysozyme = pd.DataFrame(RLyso.results.rmsd, columns=['Frame', 'Time (ns)', 'RMSD'])

# %%
# Adjusting to nanoseconds
Rgyr2KKW[:,0] = Rgyr2KKW[:,0]/1000 
#RgyrLyso[:,0] = RgyrLyso[:,0]/1000

# %%
# Rg
alpha_syn_rg = pd.DataFrame(Rgyr2KKW, columns=['Time (ns)', 'Rg'])
#lysozyme_rg = pd.DataFrame(RgyrLyso, columns=['Time (ns)', 'Rg'])

# %%
df_alpha_syn['Rg'] = alpha_syn_rg['Rg']
#dw_lysozyme['Rg'] = lysozyme_rg['Rg']

# %%
# Saving data
df_alpha_syn.to_csv('alpha-syn_data.csv')
#dw_lysozyme.to_csv('lysozyme_data.csv')

# %%
# RMSF results

print(len(RMSF_alpha_syn.rmsf))
#print(len(RMSF_lys.rmsf))
np.savetxt('alpha_syn_rmsf.csv', RMSF_alpha_syn.rmsf)
#np.savetxt('lysosyme_rmsf.csv', RMSF_lys.rmsf)

# %% [markdown]
# ### Now let's plot everything

# %%
##R2KKWCrystal =
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True

#THE FOLLOWING SHOULD BE RIGHT BUT WHY DOES IT NOT READ THE TIMESTEP?
df = pd.DataFrame(R2KKW.results.rmsd, columns=['Frame', 'Time (ns)', 'Alpha-synuclein'])
#dw = pd.DataFrame(RLyso.results.rmsd, columns=['Frame', 'Time (ns)', 'Lysozyme'])
print(df)


ax = df.plot(x='Time (ns)', y=['Alpha-synuclein'], kind='line')
#dw.plot(ax=ax, x='Time (ps)', y=['Lysozyme'], kind='line')
plt.title('RMSD over time')
ax.set_ylabel(r'RMSD($\AA$)')
plt.show()


#plt.plot(R2KKW.results.rmsd)
#plt.plot(RLyso.results.rmsd)
'''

'''

# %%
df = pd.DataFrame(Rgyr2KKW, columns=['Time (ps)', 'Alpha-synuclein'])
dw = pd.DataFrame(RgyrLyso, columns=['Time (ps)', 'Lysozyme'])
print(df)
print(dw)
# quick plot
#import matplotlib.pyplot as plt
#ax = plt.subplot(111)
#ax.plot(Rgyr[:,0], Rgyr[:,1], 'r--', lw=2, label=r"$R_G$")
ax = df.plot(x='Time (ps)', y=['Alpha-synuclein'], kind='line')
dw.plot(ax=ax, x='Time (ps)', y=['Lysozyme'], kind='line')
ax.set_xlabel("time (ps)")
ax.set_ylabel(r"radius of gyration $R_G$ ($\AA$)")
ax.figure.savefig("Rgyr.pdf")
plt.draw()
plt.title('Radius of gyration over time')

# %% [raw]
# The graph of $R_{G}(t)$ increases over time, indicating an opening up of the AdK enzyme.

# %% [markdown]
# ## Writing Coordinates

# %% [markdown]
# MDAnalysis also supports writing of data in a range of file formats (see the [Table of Supported Coordinate Formats](https://pythonhosted.org/MDAnalysis/documentation_pages/coordinates/init.html#id1) for details). MDAnalysis supports both single frame writers (such as a simple PDB or GRO file) and trajectory writers (e.g. XTC, DCD, but also multi-frame PDB files).

# %% [markdown]
# ### Single frames

# %% [markdown]
# The most straightforward way to write to a file that can only hold a single frame is to use the write() method of any AtomGroup as already also shown under Processing AtomGroups. For instance, to only write out the protein without solvent to a file in GRO format:

# %%
from MDAnalysis.tests.datafiles import PDB
uPDB = MDAnalysis.Universe(PDB)
protein = uPDB.select_atoms("protein")
protein.write("protein.gro")

# %% [markdown]
# MDAnalysis uses the file suffix to determine the output file format (unless the format keyword is specified) and will raise an exception if it is not suitable for single frame writing.

# %%
del uPDB  # clean up this example
os.unlink("protein.gro")

# %% [markdown]
# ### Trajectories

# %% [markdown]
# The typical use pattern is to
#
# 1. Get a trajectory writer with `MDAnalysis.Writer()` (which is the same as `MDAnalysis.coordinates.core.writer()`), typically specifying in advance how many atoms a frame will contain.
# 2. Use the `write()` method to write a new time step to the trajectory.
# 3. Close the trajectory with `close()` (although it is recommended to simply use the writer with the `with` statement and have the context manager close the file automatically).

# %% [markdown]
# #### Example: Protein-only trajectory

# %% [markdown]
# In practice, the second step is typically repeated in a loop as in the example below:

# %%
import MDAnalysis
from MDAnalysis.tests.datafiles import PDB, XTC

uXTC = MDAnalysis.Universe(PDB, XTC)
protein = uXTC.select_atoms("protein")
with MDAnalysis.Writer("protein.xtc", protein.n_atoms) as W:
    for ts in u.trajectory:
        W.write(protein)

# %% [markdown]
# The loop steps through the input trajectory frame by frame. The coordinates of the selection (the AtomGroup protein) change accordingly and are then written as a new frame into the output trajectory.
#
# The output trajectory only contains the coordinates of the protein. For this trajectory to be useful, a protein-only topology file also has to be stored, as in the example under Single frames.

# %%
del uXTC  # clean up this example
os.unlink("protein.xtc")

# %% [markdown]
# #### Example: Saving dynamic per-atom properties in B-factor

# %% [markdown]
# It is often very useful to project per-atom properties on the structure. A common approach is to save scalar values in the B-factor field of a PDB file and then color atoms by B-factor (also known as temperature factor or just “beta”).
#
# The following example computes the shift of each atom in AdK relative to a reference structure (line 23). We take as reference the closed conformation (after a structural superposition on the CORE domain with alignto()). The shifts are written into the B-factor with the set_bfactor() method of AtomGroup. Each frame is written out as part of a multi-frame PDB file:

# %%
# project a dynamic property on the structure using the B-factor field

import numpy as np
import MDAnalysis
import MDAnalysis.analysis.align
from MDAnalysis.core.topologyattrs import Bfactors

from MDAnalysis.tests.datafiles import PSF, DCD


u = MDAnalysis.Universe(PSF, DCD)
u.add_TopologyAttr(Bfactors(np.zeros(len(u.atoms))))
ref = MDAnalysis.Universe(PSF, DCD)  # copy of u

CORE_selection = "resid 1:29 or resid 60:121 or resid 160:214"
pdbtrj = "adk_distance_bfac.pdb"

with MDAnalysis.Writer(pdbtrj, multiframe=True, n_atoms=u.atoms.n_atoms) as PDB:
    # reference coordinates: set to first frame
    ref.trajectory[0]
    # iterate through our trajectory
    for ts in u.trajectory:
        # superimpose on the reference CORE (at t=0)
        rmsd = MDAnalysis.analysis.align.alignto(u.atoms, ref.atoms, select=CORE_selection)
        distances = np.sqrt(np.sum((u.atoms.positions - ref.atoms.positions)**2, axis=1))
        # project displacement on structure via bfactor field
        u.atoms.bfactors = distances
        PDB.write(u.atoms)
        print("Frame {0}: CORE RMSD before/after superposition: {1[0]:.1f} / {1[1]:.1f} A. "
              "min-max displacement: {2:.1f}...{3:.1f} A".format(ts.frame, rmsd, distances.min(), distances.max()))

print("Wrote PDB trajectory {0} with distances in bfactor field".format(pdbtrj))

# %% [markdown]
# ## Using the MDAnalysis.analysis Modules

# %% [markdown]
# MDAnalysis comes with a number of existing analysis code in the `MDAnalysis.analysis` module and example scripts (see also the Examples on the MDAnalysis wiki).

# %% [markdown]
# ### RMSD

# %% [markdown]
# As an example we will use the MDAnalysis.analysis.rms.rmsd() function from the MDAnalysis.analysis.rms module. It computes the coordinate root mean square distance between two sets of coordinates. For example for the AdK trajectory the backbone RMSD between first and last frame is

# %%
import MDAnalysis.analysis.rms
u = MDAnalysis.Universe(PSF, DCD)
bb = u.select_atoms('backbone')
A = bb.positions  # coordinates of first frame
u.trajectory[-1]      # forward to last frame
B = bb.positions  # coordinates of last frame
MDAnalysis.analysis.rms.rmsd(A,B)

# %% [markdown]
# ### Superposition of structure

# %% [markdown]
# In order to superimpose two structures in a way that minimizes the RMSD we have functions in the MDAnalysis.analysis.align module.
#
# The example uses files provided as part of the MDAnalysis test suite (in the variables PSF, DCD, and PDB_small). For all further examples execute first

# %%
import MDAnalysis
from MDAnalysis.analysis import align, rms
from MDAnalysis.tests.datafiles import PSF, DCD, PDB_small

# %% [markdown]
# In the simplest case, we can simply calculate the C-alpha RMSD between two structures, using rmsd():

# %%
ref = MDAnalysis.Universe(PDB_small)
mobile = MDAnalysis.Universe(PSF,DCD)
rms.rmsd(mobile.atoms.CA.positions, ref.atoms.CA.positions)

# %% [markdown]
# Note that in this example translations have not been removed. In order to look at the pure rotation one needs to superimpose the centres of mass (or geometry) first:

# %%
ref0 =  ref.atoms.CA.positions - ref.atoms.CA.center_of_mass()
mobile0 =  mobile.atoms.CA.positions - mobile.atoms.CA.center_of_mass()
rms.rmsd(mobile0, ref0)

# %% [markdown]
# The rotation matrix that superimposes mobile on ref while minimizing the CA-RMSD is obtained with the rotation_matrix() function

# %%
R, rmsd = align.rotation_matrix(mobile0, ref0)
print(rmsd)

# %%
print(R)

# %% [markdown]
# Putting all this together one can superimpose all of mobile onto ref:

# %%
mobile.atoms.translate(-mobile.atoms.CA.center_of_mass())
mobile.atoms.rotate(R)
mobile.atoms.translate(ref.atoms.CA.center_of_mass())
mobile.atoms.write("mobile_on_ref.pdb")

# %% [markdown]
# #### Exercise 5

# %% [markdown]
# Use the above in order to investigate how rigid the CORE, NMP, and LID domains are during the transition: Compute time series of the CA RMSD of each domain relative to its own starting structure, when superimposed on the starting structure.

# %% [markdown]
# The code contains a function superpose() and rmsd(). The latter is marginally faster because we only need the calculated RMSD and not the full rotation matrix. (We are calling the lower-level function MDAnalysis.core.qcprot.CalcRMSDRotationalMatrix() directly, which has somewhat non-intuitive calling conventions). superpose() also does the superposition of the mobile group to the references (but alignto() is actually a more flexible tool for doing this). Otherwise it is mostly book-keeping, which is solved by organizing everything in dictionaries with keys “CORE”, “NMP”, “LID”.

# %%
import numpy as np
from MDAnalysis.analysis.align import rotation_matrix
from MDAnalysis.lib.qcprot import CalcRMSDRotationalMatrix

def superpose(mobile, xref0, xref_com=None):
    """Superpose the AtomGroup *mobile* onto the coordinates *xref0* centered at the orgin.

    The original center of mass of the reference group *xref_com* must
    be supplied or the superposition is done at the origin of the
    coordinate system.
    """
    # 995 us
    xref_com = xref_com if xref_com is not None else np.array([0., 0., 0.])
    xmobile0 = mobile.positions - mobile.center_of_mass()
    R, rmsd = rotation_matrix(xmobile0, xref0)
    mobile.rotate(R)
    mobile.translate(xref_com)
    return rmsd

def rmsd(mobile, xref0):
    """Calculate optimal RMSD for AtomGroup *mobile* onto the coordinates *xref0* centered at the orgin.

    The coordinates are not changed. No mass weighting.
    """
    # 738 us
    xmobile0 = mobile.positions - mobile.center_of_mass()
    return CalcRMSDRotationalMatrix(xref0.T.astype(np.float64), xmobile0.T.astype(np.float64), mobile.n_atoms, None, None)


if __name__ == "__main__":
    import MDAnalysis
    import matplotlib
    import matplotlib.pyplot as plt

    # load AdK DIMS trajectory
    from MDAnalysis.tests.datafiles import PSF, DCD
    u = MDAnalysis.Universe(PSF, DCD)

    # one AtomGroup per domain
    domains = {
        'CORE': u.select_atoms("(resid 1:29 or resid 60:121 or resid 160:214) and name CA"),
        'LID': u.select_atoms("resid 122-159 and name CA"),
        'NMP': u.select_atoms("resid 30-59 and name CA"),
        }
    colors = {'CORE': 'black', 'NMP': 'blue', 'LID': 'red'}

    u.trajectory[0]   # rewind trajectory
    xref0 = dict((name, g.positions - g.center_of_mass()) for name,g in domains.iteritems())

    nframes = len(u.trajectory)
    results = dict((name, np.zeros((nframes, 2), dtype=np.float64)) for name in domains)

    for iframe,ts in enumerate(u.trajectory):
        for name, g in domains.iteritems():
            results[name][iframe, :] = u.trajectory.time, rmsd(g, xref0[name])


    # plot
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_subplot(111)
    for name in "CORE", "NMP", "LID":
        data = results[name]
        ax.plot(data[:,0], data[:,1], linestyle="-", color=colors[name], lw=2, label=name)
    ax.legend(loc="best")
    ax.set_xlabel(r"time  $t$ (ps)")
    ax.set_ylabel(r"C$_\alpha$ RMSD from $t=0$, $\rho_{\mathrm{C}_\alpha}$ ($\AA$)")

    for ext in ('svg', 'pdf', 'png'):
        fig.savefig("AdK_domain_rigidity.{0}".format(ext))
